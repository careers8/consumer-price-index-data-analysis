# %% [markdown]
# # Imports

# %%
# Print every output from a cell.
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# EDA
import numpy as np
import pandas as pd

# Visualizations
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# Plot pandas objects using plotly.
pd.options.plotting.backend = "plotly"

import cufflinks as cf
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Data Source

# %% [markdown]
# ### Data sourced from The Bureau of Labor Statistics public database ( LABSTAT ): https://download.bls.gov
# <br> BLS Consumer Price Index Data 2022: https://download.bls.gov/pub/time.series/cu/

# %% [markdown]
# # Metadata

# %% [markdown]
# ### CPI-U Description:
#
# The Consumer Price Index (CPI) All Urban Consumers (CU) is a statistical measure
# of change, over time, of the prices of goods and services in major
# expenditure groups--such as food, housing, apparel, transportation, and
# medical care--typically purchased by urban consumers. Essentially, it
# compares the cost of a sample "market basket" of goods and services in a
# specific month relative to the cost of the same "market basket" in an
# earlier reference period. This reference period is designated as the base
# period.

# %% [markdown]
# ### CPI-U Database Files:
#
#     cu.data.0.Current			-  All current year-to-date
# 	cu.data.1.AllItems			-  All items (item_code AA0, SA0)
# 	cu.data.2.Summaries			-  Summaries (item_code SA0, SAF,
# 						   SAH, SAA, SAT, SAM, SAR, SAE, SAG,
# 						   SAS, SAC)
# 	cu.data.3.AsizeNorthEast		-  A-Size areas in Northeast
# 						   (area_code A1 ...)
# 	cu.data.4.AsizeNorthCentral		-  A-size areas in North Central
# 						   (area_code A2 ...)
# 	cu.data.5.AsizeSouth			-  A-Size areas in South
# 						   (area_code A3 ...)
# 	cu.data.6.AsizeWest			-  A-Size areas in West
# 						   (area_code A4 ...)
# 	cu.data.7.OtherNorthEast		-  All other Northeast
# 						   (area_code 01, X1, D1)
# 	cu.data.8.OtherNorthCentral		-  All other North Central
# 						   (area_code 02, X2, D2)
# 	cu.data.9.OtherSouth			-  All other in South
# 						   (area_code 03, X3, D3)
# 	cu.data.10.OtherWest			-  All other in West
# 						   (area_code 04, X4)
# 	cu.data.11.USFoodBeverage		-  All US Food and Beverage
# 						   (area_code 0000, item_code SAF, SEF)
# 	cu.data.12.USHousing			-  All US Housing (area_code 0000,
# 						   item_code SAH, SEH)
# 	cu.data.13.USApparel			-  All US Apparel (area_code 0000,
# 						   item_code SAA, SEA)
# 	cu.data.14.USTransportation		-  All US Transportation (area_code
# 						   0000, item_code SAT, SET)
# 	cu.data.15.USMedical			-  All US Medical (area_code 0000,
# 						   item_code SAM, SEM, SS57)
# 	cu.data.16.USRecreation			-  All US Recreation (area_code 0000,
# 						   item_code SAR, SER, SS31, SS61, SS62)
# 	cu.data.17.USEducationAndCommunication	-  All US Education and Communication
# 						   (area_code 0000, item_code SAE,
# 						    SEE, SS27)
# 	cu.data.18.USOtherGoodsAndServices	-  All US Other Goods and Services
# 						   (area_code 0000, item_code SAG, SEG;
# 						    SS33)
# 	cu.data.19.PopulationSize		-  All Population-size (area_code
# 						   A000, X000, D000)
# 	cu.data.20.USCommoditiesServicesSpecial	-  All US Commodity and Services and
# 						   Special(area_code 0000, item_code
# 						   SA0, SAC, SAN, SAS)
# 	cu.area					-  Area codes		mapping file
# 	cu.contacts				-  Contacts for cu survey
# 	cu.footnote				-  Footnote codes	mapping file
# 	cu.item					-  Item codes		mapping file
# 	cu.MapErrors (TBR)			-  Map error codes	mapping file
# 	cu.period				-  Period codes 	mapping file
# 	cu.series				-  All series and their beginning and end dates
# 	cu.txt					-  General information

# %% [markdown]
# ### CPI-U Database Elements:
#
#     Data Element	Length		Value(Example)			Description
#
#     area_code	4		N or S, ,000-999		Unique code used to identify
# 				Ex: A100 		a specific geographic area.
#
#     area_name	80		Text 			Name of specific geographic
# 				Ex: MIAMI, FLA		area.
#
#     base_code	1		S=Standard reference 	Code identifying the type of
# 				base			base period used in index.
# 				A=Alternate reference
# 				base
#
#     base_period	20		Identifies the base  	The actual base period used
# 				period			in calculating the index.
# 				Ex: 1982-84=100
#
#     begin_period	3		M01-M13 or S01-S03	Identifies first data observation
# 				Ex: MO6=June		within the first year for which
# 				(M=Monthly, M13=Annual	data is available for a given
# 				Avg, S=Semi-Annually)	time series.
#
#     begin_year	4		YYYY			Identifies first year for which
# 				Ex: 1975		data is available for a given
# 							time series.
#
#     end_period	3		M01-M13 or S01-S03	Identifies last data observation
# 				Ex: M06=June		within the last year for which
# 				(M=Monthly, M13=Annual	data is available for a given
# 				Avg, S=Semi-Annually)	time series.
#
#     end_year	4		YYYY			Identifies last year for which
# 				Ex: 1980		data is available for a given
# 							time series.
#
#     footnote_code	1		R			Identifies footnote for the data
# 							series.
#
#     footnote_text	100		Text			Contains the text of the footnote.
#
#     item_code	8		SA0E			Identifies item for which
# 							data observations pertain.
#
#     item_name	100		Text			Full names of items.
#
#     period_abbr	5		Text	 		Abbreviation of period name.
# 				Ex: JUN
#
#     period		3		M01-M13 or S01-S03	Identifies period for which
# 				Ex: M06=June		data is observed.
# 				(M=Monthly, M13=Annual
# 				Avg, S=Semi-Annually)
#
#     period_name	20		Text		 	Full name of period to which
# 				Ex: June		the data observation refers.
#
#     periodicity_	1		S=Semi-Annual		Frequency of data
#     code				R=Regular		observation.
#
#     seasonal	1		S=Seasonally		Code identifying whether the
# 				  Adjusted 		data are seasonally adjusted.
# 				U=Unadjusted
#
#     series_id	17		CUSR0000SA0		Code identifying the specific
# 							series.
#
#     value		12		53.3			Price index for item.
#
#     year		4		YYYY			Identifies year of observation.
# 				Ex: 1990

# %% [markdown]
# # Data Acquisition

# %% [markdown]
# ### For the latest data, pull from LABSTAT the data file ( data.0.Current ) and the significant mapping files ( area, item, period, series, seasonal; footnote file is empty ):

# %%
# Define URL strings.
url = 'https://download.bls.gov/pub/time.series/'
cu = 'cu/cu.'

# Define BLS API function.
def blsAPI(string):
    return(pd.read_csv(url+cu+string,sep='\t'))

# Example dataframe for pulling cu.seasonal file from the BLS website:
example_df = blsAPI('seasonal')
example_df.head()
# Out:
#   seasonal_code            seasonal_text
# 0             S      Seasonally Adjusted
# 1             U  Not Seasonally Adjusted

# %% [markdown]
# ## CPI Data

# %% [markdown]
# ### For the latest data, pull from LABSTAT the data file ( data.0.Current ) and the significant mapping files ( area, item, period, seasonal, series; footnote file is empty ):

# %%
cpi_df = blsAPI('data.0.Current')
area_df = blsAPI('area')
item_df = blsAPI('item')
period_df = blsAPI('period')
seasonal_df = blsAPI('seasonal')
series_df = blsAPI('series')

# %% [markdown]
# # EDA

# %% [markdown]
# ## area_df

# %%
area_df.head()
area_df.info()
# Out:
#   area_code          area_name  display_level selectable  sort_sequence
# 0      0000  U.S. city average              0          T              1
# 1      0100          Northeast              0          T              5
# 2      0110        New England              1          T             10
# 3      0120    Middle Atlantic              1          T             11
# 4      0200            Midwest              0          T             14
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   area_code      58 non-null     object
#  1   area_name      58 non-null     object
#  2   display_level  58 non-null     int64
#  3   selectable     58 non-null     object
#  4   sort_sequence  58 non-null     int64
# dtypes: int64(2), object(3)
# memory usage: 2.4+ KB

# %% [markdown]
# ### All of the area codes are 4 digits long.

# %%
area_df['area_code'].apply(len).value_counts()
# Out:
# 4    58
# Name: area_code, dtype: int64

# %% [markdown]
# ### There are 58 unique area codes, each corresponding to some region ( the meaning of some, like 'West - Size Class A', are not readily apparent; size class may have to do with population ).

# %%
area_df.nunique()
area_df['area_name'].unique()
# Out:
# area_code        58
# area_name        58
# display_level     2
# selectable        1
# sort_sequence    58
# dtype: int64
# array(['U.S. city average', 'Northeast', 'New England', 'Middle Atlantic',
#        'Midwest', 'East North Central', 'West North Central', 'South',
#        'South Atlantic', 'East South Central', 'West South Central',
#        'West', 'Mountain', 'Pacific', 'Pittsburgh, PA',
#        'Cleveland-Akron, OH', 'Milwaukee-Racine, WI',
#        'Cincinnati-Hamilton, OH-KY-IN', 'Kansas City, MO-KS',
#        'Washington-Baltimore, DC-MD-VA-WV',
#        'Los Angeles-Riverside-Orange County, CA', 'Portland-Salem, OR-WA',
#        'Size Class D', 'Midwest - Size Class D', 'South - Size Class D',
#        'Size Class B/C', 'Northeast - Size Class B/C',
#        'Midwest - Size Class B/C', 'South - Size Class B/C',
#        'West - Size Class B/C', 'Size Class A',
#        'Northeast - Size Class A', 'Boston-Cambridge-Newton, MA-NH',
#        'New York-Newark-Jersey City, NY-NJ-PA',
#        'Philadelphia-Camden-Wilmington, PA-NJ-DE-MD',
#        'Midwest - Size Class A', 'Chicago-Naperville-Elgin, IL-IN-WI',
#        'Detroit-Warren-Dearborn, MI',
#        'Minneapolis-St.Paul-Bloomington, MN-WI', 'St. Louis, MO-IL',
#        'South - Size Class A',
#        'Washington-Arlington-Alexandria, DC-VA-MD-WV',
#        'Miami-Fort Lauderdale-West Palm Beach, FL',
#        'Atlanta-Sandy Springs-Roswell, GA',
#        'Tampa-St. Petersburg-Clearwater, FL',
#        'Baltimore-Columbia-Towson, MD', 'Dallas-Fort Worth-Arlington, TX',
#        'Houston-The Woodlands-Sugar Land, TX', 'West - Size Class A',
#        'Phoenix-Mesa-Scottsdale, AZ', 'Denver-Aurora-Lakewood, CO',
#        'Los Angeles-Long Beach-Anaheim, CA',
#        'San Francisco-Oakland-Hayward, CA',
#        'Riverside-San Bernardino-Ontario, CA',
#        'Seattle-Tacoma-Bellevue WA', 'San Diego-Carlsbad, CA',
#        'Urban Hawaii', 'Urban Alaska'], dtype=object)

# %% [markdown]
# ## cpi_df

# %%
cpi_df.head()
cpi_df.info()
# Out:
#    series_id          year period         value  footnote_codes
# 0  CUSR0000SA0        1997    M01         159.4             NaN
# 1  CUSR0000SA0        1997    M02         159.7             NaN
# 2  CUSR0000SA0        1997    M03         159.8             NaN
# 3  CUSR0000SA0        1997    M04         159.9             NaN
# 4  CUSR0000SA0        1997    M05         159.9             NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 960933 entries, 0 to 960932
# Data columns (total 5 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   series_id          960933 non-null  object
#  1   year               960933 non-null  int64
#  2   period             960933 non-null  object
#  3          value       960933 non-null  float64
#  4   footnote_codes     0 non-null       float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 36.7+ MB

# %% [markdown]
# ### The series_id and value feature names contain tabs; let's remove them.

# %%
cpi_df.columns
cpi_df = cpi_df.rename(columns={'series_id        ':'series_id', '       value':'value'})
cpi_df.columns
# Out:
# Index(['series_id        ', 'year', 'period', '       value',
#        'footnote_codes'],
#       dtype='object')
# Index(['series_id', 'year', 'period', 'value', 'footnote_codes'], dtype='object')

# %% [markdown]
# ### The footnote_codes values are all null; let's drop this feature.

# %%
cpi_df.head()
cpi_df = cpi_df.drop(['footnote_codes'],axis=1)
cpi_df.head()
# Out:
#            series_id  year period  value  footnote_codes
# 0  CUSR0000SA0        1997    M01  159.4             NaN
# 1  CUSR0000SA0        1997    M02  159.7             NaN
# 2  CUSR0000SA0        1997    M03  159.8             NaN
# 3  CUSR0000SA0        1997    M04  159.9             NaN
# 4  CUSR0000SA0        1997    M05  159.9             NaN
#            series_id  year period  value
# 0  CUSR0000SA0        1997    M01  159.4
# 1  CUSR0000SA0        1997    M02  159.7
# 2  CUSR0000SA0        1997    M03  159.8
# 3  CUSR0000SA0        1997    M04  159.9
# 4  CUSR0000SA0        1997    M05  159.9

# %% [markdown]
# ## item_df

# %%
item_df.head()
item_df.info()
# Out:
#   item_code                                          item_name  display_level  \
# 0       AA0                               All items - old base              0
# 1      AA0R  Purchasing power of the consumer dollar - old ...              0
# 2       SA0                                          All items              0
# 3      SA0E                                             Energy              1
# 4     SA0L1                                All items less food              1
#
#   selectable  sort_sequence
# 0          T              2
# 1          T            400
# 2          T              1
# 3          T            375
# 4          T            359
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   item_code      400 non-null    object
#  1   item_name      400 non-null    object
#  2   display_level  400 non-null    int64
#  3   selectable     400 non-null    object
#  4   sort_sequence  400 non-null    int64
# dtypes: int64(2), object(3)
# memory usage: 15.8+ KB

# %% [markdown]
# ### There are 400 unique item_code values, each corresponding to some good or service specified in the item_name feature.

# %%
item_df.nunique()
item_df['item_name'].unique()
# Out:
# item_code        400
# item_name        400
# display_level      9
# selectable         1
# sort_sequence    400
# dtype: int64
# array(['All items - old base',
#        'Purchasing power of the consumer dollar - old base', 'All items',
#        'Energy', 'All items less food', 'All items less food and shelter',
#        'All items less food, shelter, and energy',
#        'All items less food, shelter, energy, and used cars and trucks',
#        'All items less food and energy', 'All items less shelter',
#        'All items less medical care', 'All items less energy',
#        'Purchasing power of the consumer dollar', 'Apparel less footwear',
#        'Apparel', "Men's and boys' apparel", "Women's and girls' apparel",
#        'Commodities', 'Energy commodities', 'Commodities less food',
#        'Commodities less food and beverages',
#        'Commodities less food and energy commodities',
#        'Commodities less food, energy, and used cars and trucks',
#        'Durables', 'Education and communication', 'Education',
#        'Communication', 'Information and information processing',
#        'Education and communication commodities',
#        'Education and communication services', 'Food and beverages',
#        'Food', 'Food at home', 'Cereals and bakery products',
#        'Meats, poultry, fish, and eggs', 'Meats, poultry, and fish',
#        'Meats', 'Fruits and vegetables', 'Fresh fruits and vegetables',
#        'Nonalcoholic beverages and beverage materials',
#        'Other food at home', 'Alcoholic beverages',
#        'Other goods and services', 'Personal care', 'Other goods',
#        'Other personal services', 'Housing', 'Shelter',
#        'Fuels and utilities', 'Household energy',
#        'Household furnishings and operations',
#        'Household furnishings and supplies', 'Medical care',
#        'Medical care commodities', 'Medical care services', 'Nondurables',
#        'Domestically produced farm food', 'Nondurables less food',
#        'Nondurables less food and beverages',
#        'Nondurables less food, beverages, and apparel',
#        'Nondurables less food and apparel', 'Recreation',
#        'Recreation commodities', 'Recreation services', 'Services',
#        'Utilities and public transportation', 'Rent of shelter',
#        'Other services', 'Transportation services',
#        'Services less rent of shelter',
#        'Services less medical care services',
#        'Services less energy services', 'Transportation',
#        'Private transportation',
#        'Transportation commodities less motor fuel', "Men's apparel",
#        "Men's suits, sport coats, and outerwear",
#        "Men's underwear, nightwear, swimwear and accessories",
#        "Men's shirts and sweaters", "Men's pants and shorts",
#        "Boys' apparel", "Women's apparel", "Women's outerwear",
#        "Women's dresses", "Women's suits and separates",
#        "Women's underwear, nightwear, swimwear and accessories",
#        "Girls' apparel", 'Footwear', "Men's footwear",
#        "Boys' and girls' footwear", "Women's footwear",
#        "Infants' and toddlers' apparel", 'Jewelry and watches', 'Watches',
#        'Jewelry', 'Educational books and supplies',
#        'Tuition, other school fees, and childcare',
#        'College tuition and fees',
#        'Elementary and high school tuition and fees',
#        'Day care and preschool',
#        'Technical and business school tuition and fees',
#        'Postage and delivery services', 'Postage', 'Delivery services',
#        'Telephone services', 'Wireless telephone services',
#        'Residential telephone services',
#        'Information technology, hardware and services',
#        'Computers, peripherals, and smart home assistants',
#        'Computer software and accessories',
#        'Internet services and electronic information providers',
#        'Telephone hardware, calculators, and other consumer information items',
#        'Information technology commodities',
#        'Cereals and cereal products', 'Flour and prepared flour mixes',
#        'Breakfast cereal', 'Rice, pasta, cornmeal', 'Bakery products',
#        'Bread', 'Fresh biscuits, rolls, muffins',
#        'Cakes, cupcakes, and cookies', 'Other bakery products',
#        'Beef and veal', 'Uncooked ground beef', 'Uncooked beef roasts',
#        'Uncooked beef steaks', 'Uncooked other beef and veal', 'Pork',
#        'Bacon, breakfast sausage, and related products', 'Ham',
#        'Pork chops', 'Other pork including roasts, steaks, and ribs',
#        'Other meats', 'Poultry', 'Chicken',
#        'Other uncooked poultry including turkey', 'Fish and seafood',
#        'Fresh fish and seafood', 'Processed fish and seafood', 'Eggs',
#        'Dairy and related products', 'Milk',
#        'Cheese and related products', 'Ice cream and related products',
#        'Other dairy and related products', 'Fresh fruits', 'Apples',
#        'Bananas', 'Citrus fruits', 'Other fresh fruits',
#        'Fresh vegetables', 'Potatoes', 'Lettuce', 'Tomatoes',
#        'Other fresh vegetables', 'Processed fruits and vegetables',
#        'Canned fruits and vegetables', 'Frozen fruits and vegetables',
#        'Other processed fruits and vegetables including dried',
#        'Juices and nonalcoholic drinks', 'Carbonated drinks',
#        'Frozen noncarbonated juices and drinks',
#        'Nonfrozen noncarbonated juices and drinks',
#        'Beverage materials including coffee and tea', 'Coffee',
#        'Other beverage materials including tea', 'Sugar and sweets',
#        'Sugar and sugar substitutes', 'Candy and chewing gum',
#        'Other sweets', 'Fats and oils', 'Butter and margarine',
#        'Salad dressing', 'Other fats and oils including peanut butter',
#        'Other foods', 'Soups', 'Frozen and freeze dried prepared foods',
#        'Snacks', 'Spices, seasonings, condiments, sauces', 'Baby food',
#        'Other miscellaneous foods', 'Food away from home',
#        'Full service meals and snacks',
#        'Limited service meals and snacks',
#        'Food at employee sites and schools',
#        'Food from vending machines and mobile vendors',
#        'Other food away from home', 'Alcoholic beverages at home',
#        'Beer, ale, and other malt beverages at home',
#        'Distilled spirits at home', 'Wine at home',
#        'Alcoholic beverages away from home',
#        'Tobacco and smoking products', 'Cigarettes',
#        'Tobacco products other than cigarettes', 'Personal care products',
#        'Hair, dental, shaving, and miscellaneous personal care products',
#        'Cosmetics, perfume, bath, nail preparations and implements',
#        'Personal care services',
#        'Haircuts and other personal care services',
#        'Miscellaneous personal services', 'Legal services',
#        'Funeral expenses', 'Laundry and dry cleaning services',
#        'Apparel services other than laundry and dry cleaning',
#        'Financial services', 'Miscellaneous personal goods',
#        'Rent of primary residence', 'Lodging away from home',
#        'Housing at school, excluding board',
#        'Other lodging away from home including hotels and motels',
#        "Owners' equivalent rent of residences",
#        "Owners' equivalent rent of primary residence",
#        "Tenants' and household insurance", 'Fuel oil and other fuels',
#        'Fuel oil', 'Propane, kerosene, and firewood', 'Energy services',
#        'Electricity', 'Utility (piped) gas service',
#        'Water and sewer and trash collection services',
#        'Water and sewerage maintenance', 'Garbage and trash collection',
#        'Window and floor coverings and other linens', 'Floor coverings',
#        'Window coverings', 'Other linens', 'Furniture and bedding',
#        'Bedroom furniture',
#        'Living room, kitchen, and dining room furniture',
#        'Other furniture', 'Appliances', 'Major appliances',
#        'Other appliances', 'Other household equipment and furnishings',
#        'Clocks, lamps, and decorator items', 'Indoor plants and flowers',
#        'Dishes and flatware', 'Nonelectric cookware and tableware',
#        'Tools, hardware, outdoor equipment and supplies',
#        'Tools, hardware and supplies', 'Outdoor equipment and supplies',
#        'Housekeeping supplies', 'Household cleaning products',
#        'Household paper products', 'Miscellaneous household products',
#        'Household operations', 'Domestic services',
#        'Gardening and lawncare services',
#        'Moving, storage, freight expense', 'Repair of household items',
#        'Professional services', "Physicians' services", 'Dental services',
#        'Eyeglasses and eye care',
#        'Services by other medical professionals',
#        'Hospital and related services', 'Hospital services',
#        'Nursing homes and adult day services',
#        'Care of invalids and elderly at home', 'Health insurance',
#        'Medicinal drugs', 'Prescription drugs', 'Nonprescription drugs',
#        'Medical equipment and supplies', 'Video and audio', 'Televisions',
#        'Cable and satellite television service', 'Other video equipment',
#        'Video discs and other media, including rental of video',
#        'Audio equipment', 'Recorded music and music subscriptions',
#        'Video and audio products', 'Video and audio services',
#        'Pets, pet products and services', 'Pets and pet products',
#        'Pet services including veterinary', 'Sporting goods',
#        'Sports vehicles including bicycles', 'Sports equipment',
#        'Photography', 'Photographic equipment and supplies',
#        'Photographers and photo processing', 'Other recreational goods',
#        'Toys', 'Sewing machines, fabric and supplies',
#        'Music instruments and accessories', 'Other recreation services',
#        'Club membership for shopping clubs, fraternal, or other organizations, or participant sports fees',
#        'Admissions', 'Fees for lessons or instructions',
#        'Recreational reading materials', 'Newspapers and magazines',
#        'Recreational books', 'New and used motor vehicles',
#        'New vehicles', 'Used cars and trucks', 'Leased cars and trucks',
#        'Car and truck rental', 'Motor fuel', 'Gasoline (all types)',
#        'Other motor fuels', 'Motor vehicle parts and equipment', 'Tires',
#        'Vehicle accessories other than tires',
#        'Motor vehicle maintenance and repair', 'Motor vehicle body work',
#        'Motor vehicle maintenance and servicing', 'Motor vehicle repair',
#        'Motor vehicle insurance', 'Motor vehicle fees',
#        'State motor vehicle registration and license fees',
#        'Parking and other fees', 'Public transportation', 'Airline fares',
#        'Other intercity transportation', 'Intracity transportation',
#        'Rice', 'White bread', 'Bread other than white',
#        'Fresh cakes and cupcakes', 'Cookies',
#        'Fresh sweetrolls, coffeecakes, doughnuts',
#        'Crackers, bread, and cracker products',
#        'Frozen and refrigerated bakery products, pies, tarts, turnovers',
#        'Bacon and related products',
#        'Breakfast sausage and related products', 'Ham, excluding canned',
#        'Frankfurters', 'Lamb and organ meats', 'Lamb and mutton',
#        'Lunchmeats', 'Fresh whole chicken',
#        'Fresh and frozen chicken parts', 'Shelf stable fish and seafood',
#        'Frozen fish and seafood', 'Fresh whole milk',
#        'Fresh milk other than whole', 'Butter',
#        'Oranges, including tangerines', 'Canned fruits',
#        'Frozen vegetables', 'Canned vegetables',
#        'Dried beans, peas, and lentils', 'Margarine', 'Peanut butter',
#        'Roasted coffee', 'Instant coffee',
#        'Salt and other seasonings and spices',
#        'Olives, pickles, relishes', 'Sauces and gravies',
#        'Other condiments', 'Prepared salads', 'Whiskey at home',
#        'Distilled spirits, excluding whiskey, at home',
#        'Beer, ale, and other malt beverages away from home',
#        'Wine away from home', 'Distilled spirits away from home',
#        'Land-line interstate toll calls',
#        'Land-line intrastate toll calls', 'Laundry equipment',
#        'Video discs and other media',
#        'Video game hardware, software and accessories',
#        'Stationery, stationery supplies, gift wrap', 'New cars',
#        'New cars and trucks', 'New trucks', 'New motorcycles',
#        'Gasoline, unleaded regular', 'Gasoline, unleaded midgrade',
#        'Gasoline, unleaded premium', 'Motor oil, coolant, and fluids',
#        'Vehicle parts and equipment other than tires',
#        'Parking fees and tolls', 'Intercity bus fare',
#        'Intercity train fare', 'Ship fare', 'Intracity mass transit',
#        'Inpatient hospital services', 'Outpatient hospital services',
#        'Toys, games, hobbies and playground equipment',
#        'Film and photographic supplies', 'Photographic equipment',
#        'Pet food', 'Purchase of pets, pet supplies, accessories',
#        'Automobile service clubs',
#        'Admission to movies, theaters, and concerts',
#        'Admission to sporting events', 'Photographer fees',
#        'Photo Processing', 'Pet services', 'Veterinarian services',
#        'Rental of video discs and other media',
#        'Checking account and other bank services',
#        'Tax return preparation and other accounting fees',
#        'College textbooks', 'Smartphones',
#        'Food at elementary and secondary schools', "Infants' equipment",
#        "Infants' furniture"], dtype=object)

# %% [markdown]
# ## period_df

# %% [markdown]
# ### There are 16 unique periods, 12 corresponding to the months of the year, and 4 corresponding to an annual average ( one averaged over 12 months, other averaged over 2 half-years; should be equal? ).

# %%
period_df
# Out:
#    period period_abbr     period_name
# 0     M01         JAN         January
# 1     M02         FEB        February
# 2     M03         MAR           March
# 3     M04         APR           April
# 4     M05         MAY             May
# 5     M06         JUN            June
# 6     M07         JUL            July
# 7     M08         AUG          August
# 8     M09         SEP       September
# 9     M10         OCT         October
# 10    M11         NOV        November
# 11    M12         DEC        December
# 12    M13       AN AV  Annual Average
# 13    S01       HALF1      First Half
# 14    S02       HALF2     Second Half
# 15    S03       AN AV  Annual Average

# %% [markdown]
# ## seasonal_df

# %% [markdown]
# ### The seasonal_df values are binary.

# %%
seasonal_df
# Out:
#   seasonal_code            seasonal_text
# 0             S      Seasonally Adjusted
# 1             U  Not Seasonally Adjusted

# %%
# # Encode as dummy variables.
# pd.get_dummies(seasonal_df['seasonal_code'])

# %% [markdown]
# ## series_df

# %%
series_df.head()
series_df.info()
# Out:
#    series_id         area_code item_code seasonal periodicity_code base_code  \
# 0  CUSR0000SA0            0000       SA0        S                R         S
# 1  CUSR0000SA0E           0000      SA0E        S                R         S
# 2  CUSR0000SA0L1          0000     SA0L1        S                R         S
# 3  CUSR0000SA0L12         0000    SA0L12        S                R         S
# 4  CUSR0000SA0L12E        0000   SA0L12E        S                R         S
#
#    base_period                                       series_title  \
# 0  1982-84=100  All items in U.S. city average, all urban cons...
# 1  1982-84=100  Energy in U.S. city average, all urban consume...
# 2  1982-84=100  All items less food in U.S. city average, all ...
# 3  1982-84=100  All items less food and shelter in U.S. city a...
# 4  1982-84=100  All items less food, shelter, and energy in U....
#
#    footnote_codes  begin_year begin_period  end_year end_period
# 0             NaN        1947          M01      2022        M06
# 1             NaN        1957          M01      2022        M06
# 2             NaN        1947          M01      2022        M06
# 3             NaN        1967          M01      2022        M06
# 4             NaN        1967          M01      2022        M06
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8096 entries, 0 to 8095
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   series_id          8096 non-null   object
#  1   area_code          8096 non-null   object
#  2   item_code          8096 non-null   object
#  3   seasonal           8096 non-null   object
#  4   periodicity_code   8096 non-null   object
#  5   base_code          8096 non-null   object
#  6   base_period        8096 non-null   object
#  7   series_title       8096 non-null   object
#  8   footnote_codes     0 non-null      float64
#  9   begin_year         8096 non-null   int64
#  10  begin_period       8096 non-null   object
#  11  end_year           8096 non-null   int64
#  12  end_period         8096 non-null   object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 822.4+ KB

# %% [markdown]
# ### The series_id feature name contains a tab whitespace; let's remove it.

# %%
series_df.columns
series_df = series_df.rename(columns={'series_id        ':'series_id'})
series_df.columns
# Out:
# Index(['series_id        ', 'area_code', 'item_code', 'seasonal',
#        'periodicity_code', 'base_code', 'base_period', 'series_title',
#        'footnote_codes', 'begin_year', 'begin_period', 'end_year',
#        'end_period'],
#       dtype='object')
# Index(['series_id', 'area_code', 'item_code', 'seasonal', 'periodicity_code',
#        'base_code', 'base_period', 'series_title', 'footnote_codes',
#        'begin_year', 'begin_period', 'end_year', 'end_period'],
#       dtype='object')

# %% [markdown]
# ### There are 8096 unique series_id values, but only 4229 unique series_title values.

# %%
series_df.nunique()
series_df['series_title'].unique()
# Out:
# series_id           8096
# area_code             58
# item_code            400
# seasonal               2
# periodicity_code       2
# base_code              2
# base_period           27
# series_title        4229
# footnote_codes         0
# begin_year            65
# begin_period          16
# end_year              12
# end_period            12
# dtype: int64
# array(['All items in U.S. city average, all urban consumers, seasonally adjusted',
#        'Energy in U.S. city average, all urban consumers, seasonally adjusted',
#        'All items less food in U.S. city average, all urban consumers, seasonally adjusted',
#        ...,
#        'Household furnishings and supplies in Portland-Salem, OR-WA, all urban consumers, not seasonally adjusted',
#        'Transportation commodities less motor fuel in Portland-Salem, OR-WA, all urban consumers, not seasonally adjusted',
#        'Gasoline, unleaded midgrade in Portland-Salem, OR-WA, all urban consumers, not seasonally adjusted'],
#       dtype=object)

# %% [markdown]
# ### The series_title values are of the form: '{item_name} in {area_name}, all urban consumers, {seasonal_text}'.

# %%
series_df['series_title'][0]
# Out:
# 'All items in U.S. city average, all urban consumers, seasonally adjusted'

# %%
series_df[series_df['series_title'].str.contains('all items',case=False,na=False)]
# Out:
#               series_id area_code item_code seasonal periodicity_code  \
# 0     CUSR0000SA0            0000       SA0        S                R
# 2     CUSR0000SA0L1          0000     SA0L1        S                R
# 3     CUSR0000SA0L12         0000    SA0L12        S                R
# 4     CUSR0000SA0L12E        0000   SA0L12E        S                R
# 5     CUSR0000SA0L12E4       0000  SA0L12E4        S                R
# ...                 ...       ...       ...      ...              ...
# 8035  CUUSS49GSA0            S49G       SA0        U                S
# 8037  CUUSS49GSA0L1E         S49G    SA0L1E        U                S
# 8038  CUUSS49GSA0L2          S49G     SA0L2        U                S
# 8039  CUUSS49GSA0L5          S49G     SA0L5        U                S
# 8040  CUUSS49GSA0LE          S49G     SA0LE        U                S
#
#      base_code  base_period  \
# 0            S  1982-84=100
# 2            S  1982-84=100
# 3            S  1982-84=100
# 4            S  1982-84=100
# 5            S  1982-84=100
# ...        ...          ...
# 8035         S  1982-84=100
# 8037         S  1982-84=100
# 8038         S  1982-84=100
# 8039         S  1982-84=100
# 8040         S  1982-84=100
#
#                                            series_title  footnote_codes  \
# 0     All items in U.S. city average, all urban cons...             NaN
# 2     All items less food in U.S. city average, all ...             NaN
# 3     All items less food and shelter in U.S. city a...             NaN
# 4     All items less food, shelter, and energy in U....             NaN
# 5     All items less food, shelter, energy, and used...             NaN
# ...                                                 ...             ...
# 8035  All items in Urban Alaska, all urban consumers...             NaN
# 8037  All items less food and energy in Urban Alaska...             NaN
# 8038  All items less shelter in Urban Alaska, all ur...             NaN
# 8039  All items less medical care in Urban Alaska, a...             NaN
# 8040  All items less energy in Urban Alaska, all urb...             NaN
#
#       begin_year begin_period  end_year end_period
# 0           1947          M01      2022        M06
# 2           1947          M01      2022        M06
# 3           1967          M01      2022        M06
# 4           1967          M01      2022        M06
# 5           1967          M01      2022        M06
# ...          ...          ...       ...        ...
# 8035        1984          S01      2022        S01
# 8037        1984          S01      2022        S01
# 8038        1984          S01      2022        S01
# 8039        1984          S01      2022        S01
# 8040        1984          S01      2022        S01
#
# [695 rows x 13 columns]

# %% [markdown]
# ### The various types of items that we are looking at.

# %%
items = []
for string in item_df['item_name'].unique():
    items.append(string.split(',')[0])
set(items)
# Out:
# {'Admission to movies',
#  'Admission to sporting events',
#  'Admissions',
#  'Airline fares',
#  'Alcoholic beverages',
#  'Alcoholic beverages at home',
#  'Alcoholic beverages away from home',
#  'All items',
#  'All items - old base',
#  'All items less energy',
#  'All items less food',
#  'All items less food and energy',
#  'All items less food and shelter',
#  'All items less medical care',
#  'All items less shelter',
#  'Apparel',
#  'Apparel less footwear',
#  'Apparel services other than laundry and dry cleaning',
#  'Apples',
#  'Appliances',
#  'Audio equipment',
#  'Automobile service clubs',
#  'Baby food',
#  'Bacon',
#  'Bacon and related products',
#  'Bakery products',
#  'Bananas',
#  'Bedroom furniture',
#  'Beef and veal',
#  'Beer',
#  'Beverage materials including coffee and tea',
#  "Boys' and girls' footwear",
#  "Boys' apparel",
#  'Bread',
#  'Bread other than white',
#  'Breakfast cereal',
#  'Breakfast sausage and related products',
#  'Butter',
#  'Butter and margarine',
#  'Cable and satellite television service',
#  'Cakes',
#  'Candy and chewing gum',
#  'Canned fruits',
#  'Canned fruits and vegetables',
#  'Canned vegetables',
#  'Car and truck rental',
#  'Carbonated drinks',
#  'Care of invalids and elderly at home',
#  'Cereals and bakery products',
#  'Cereals and cereal products',
#  'Checking account and other bank services',
#  'Cheese and related products',
#  'Chicken',
#  'Cigarettes',
#  'Citrus fruits',
#  'Clocks',
#  'Club membership for shopping clubs',
#  'Coffee',
#  'College textbooks',
#  'College tuition and fees',
#  'Commodities',
#  'Commodities less food',
#  'Commodities less food and beverages',
#  'Commodities less food and energy commodities',
#  'Communication',
#  'Computer software and accessories',
#  'Computers',
#  'Cookies',
#  'Cosmetics',
#  'Crackers',
#  'Dairy and related products',
#  'Day care and preschool',
#  'Delivery services',
#  'Dental services',
#  'Dishes and flatware',
#  'Distilled spirits',
#  'Distilled spirits at home',
#  'Distilled spirits away from home',
#  'Domestic services',
#  'Domestically produced farm food',
#  'Dried beans',
#  'Durables',
#  'Education',
#  'Education and communication',
#  'Education and communication commodities',
#  'Education and communication services',
#  'Educational books and supplies',
#  'Eggs',
#  'Electricity',
#  'Elementary and high school tuition and fees',
#  'Energy',
#  'Energy commodities',
#  'Energy services',
#  'Eyeglasses and eye care',
#  'Fats and oils',
#  'Fees for lessons or instructions',
#  'Film and photographic supplies',
#  'Financial services',
#  'Fish and seafood',
#  'Floor coverings',
#  'Flour and prepared flour mixes',
#  'Food',
#  'Food and beverages',
#  'Food at elementary and secondary schools',
#  'Food at employee sites and schools',
#  'Food at home',
#  'Food away from home',
#  'Food from vending machines and mobile vendors',
#  'Footwear',
#  'Frankfurters',
#  'Fresh and frozen chicken parts',
#  'Fresh biscuits',
#  'Fresh cakes and cupcakes',
#  'Fresh fish and seafood',
#  'Fresh fruits',
#  'Fresh fruits and vegetables',
#  'Fresh milk other than whole',
#  'Fresh sweetrolls',
#  'Fresh vegetables',
#  'Fresh whole chicken',
#  'Fresh whole milk',
#  'Frozen and freeze dried prepared foods',
#  'Frozen and refrigerated bakery products',
#  'Frozen fish and seafood',
#  'Frozen fruits and vegetables',
#  'Frozen noncarbonated juices and drinks',
#  'Frozen vegetables',
#  'Fruits and vegetables',
#  'Fuel oil',
#  'Fuel oil and other fuels',
#  'Fuels and utilities',
#  'Full service meals and snacks',
#  'Funeral expenses',
#  'Furniture and bedding',
#  'Garbage and trash collection',
#  'Gardening and lawncare services',
#  'Gasoline',
#  'Gasoline (all types)',
#  "Girls' apparel",
#  'Hair',
#  'Haircuts and other personal care services',
#  'Ham',
#  'Health insurance',
#  'Hospital and related services',
#  'Hospital services',
#  'Household cleaning products',
#  'Household energy',
#  'Household furnishings and operations',
#  'Household furnishings and supplies',
#  'Household operations',
#  'Household paper products',
#  'Housekeeping supplies',
#  'Housing',
#  'Housing at school',
#  'Ice cream and related products',
#  'Indoor plants and flowers',
#  "Infants' and toddlers' apparel",
#  "Infants' equipment",
#  "Infants' furniture",
#  'Information and information processing',
#  'Information technology',
#  'Information technology commodities',
#  'Inpatient hospital services',
#  'Instant coffee',
#  'Intercity bus fare',
#  'Intercity train fare',
#  'Internet services and electronic information providers',
#  'Intracity mass transit',
#  'Intracity transportation',
#  'Jewelry',
#  'Jewelry and watches',
#  'Juices and nonalcoholic drinks',
#  'Lamb and mutton',
#  'Lamb and organ meats',
#  'Land-line interstate toll calls',
#  'Land-line intrastate toll calls',
#  'Laundry and dry cleaning services',
#  'Laundry equipment',
#  'Leased cars and trucks',
#  'Legal services',
#  'Lettuce',
#  'Limited service meals and snacks',
#  'Living room',
#  'Lodging away from home',
#  'Lunchmeats',
#  'Major appliances',
#  'Margarine',
#  'Meats',
#  'Medical care',
#  'Medical care commodities',
#  'Medical care services',
#  'Medical equipment and supplies',
#  'Medicinal drugs',
#  "Men's and boys' apparel",
#  "Men's apparel",
#  "Men's footwear",
#  "Men's pants and shorts",
#  "Men's shirts and sweaters",
#  "Men's suits",
#  "Men's underwear",
#  'Milk',
#  'Miscellaneous household products',
#  'Miscellaneous personal goods',
#  'Miscellaneous personal services',
#  'Motor fuel',
#  'Motor oil',
#  'Motor vehicle body work',
#  'Motor vehicle fees',
#  'Motor vehicle insurance',
#  'Motor vehicle maintenance and repair',
#  'Motor vehicle maintenance and servicing',
#  'Motor vehicle parts and equipment',
#  'Motor vehicle repair',
#  'Moving',
#  'Music instruments and accessories',
#  'New and used motor vehicles',
#  'New cars',
#  'New cars and trucks',
#  'New motorcycles',
#  'New trucks',
#  'New vehicles',
#  'Newspapers and magazines',
#  'Nonalcoholic beverages and beverage materials',
#  'Nondurables',
#  'Nondurables less food',
#  'Nondurables less food and apparel',
#  'Nondurables less food and beverages',
#  'Nonelectric cookware and tableware',
#  'Nonfrozen noncarbonated juices and drinks',
#  'Nonprescription drugs',
#  'Nursing homes and adult day services',
#  'Olives',
#  'Oranges',
#  'Other appliances',
#  'Other bakery products',
#  'Other beverage materials including tea',
#  'Other condiments',
#  'Other dairy and related products',
#  'Other fats and oils including peanut butter',
#  'Other food at home',
#  'Other food away from home',
#  'Other foods',
#  'Other fresh fruits',
#  'Other fresh vegetables',
#  'Other furniture',
#  'Other goods',
#  'Other goods and services',
#  'Other household equipment and furnishings',
#  'Other intercity transportation',
#  'Other linens',
#  'Other lodging away from home including hotels and motels',
#  'Other meats',
#  'Other miscellaneous foods',
#  'Other motor fuels',
#  'Other personal services',
#  'Other pork including roasts',
#  'Other processed fruits and vegetables including dried',
#  'Other recreation services',
#  'Other recreational goods',
#  'Other services',
#  'Other sweets',
#  'Other uncooked poultry including turkey',
#  'Other video equipment',
#  'Outdoor equipment and supplies',
#  'Outpatient hospital services',
#  "Owners' equivalent rent of primary residence",
#  "Owners' equivalent rent of residences",
#  'Parking and other fees',
#  'Parking fees and tolls',
#  'Peanut butter',
#  'Personal care',
#  'Personal care products',
#  'Personal care services',
#  'Pet food',
#  'Pet services',
#  'Pet services including veterinary',
#  'Pets',
#  'Pets and pet products',
#  'Photo Processing',
#  'Photographer fees',
#  'Photographers and photo processing',
#  'Photographic equipment',
#  'Photographic equipment and supplies',
#  'Photography',
#  "Physicians' services",
#  'Pork',
#  'Pork chops',
#  'Postage',
#  'Postage and delivery services',
#  'Potatoes',
#  'Poultry',
#  'Prepared salads',
#  'Prescription drugs',
#  'Private transportation',
#  'Processed fish and seafood',
#  'Processed fruits and vegetables',
#  'Professional services',
#  'Propane',
#  'Public transportation',
#  'Purchase of pets',
#  'Purchasing power of the consumer dollar',
#  'Purchasing power of the consumer dollar - old base',
#  'Recorded music and music subscriptions',
#  'Recreation',
#  'Recreation commodities',
#  'Recreation services',
#  'Recreational books',
#  'Recreational reading materials',
#  'Rent of primary residence',
#  'Rent of shelter',
#  'Rental of video discs and other media',
#  'Repair of household items',
#  'Residential telephone services',
#  'Rice',
#  'Roasted coffee',
#  'Salad dressing',
#  'Salt and other seasonings and spices',
#  'Sauces and gravies',
#  'Services',
#  'Services by other medical professionals',
#  'Services less energy services',
#  'Services less medical care services',
#  'Services less rent of shelter',
#  'Sewing machines',
#  'Shelf stable fish and seafood',
#  'Shelter',
#  'Ship fare',
#  'Smartphones',
#  'Snacks',
#  'Soups',
#  'Spices',
#  'Sporting goods',
#  'Sports equipment',
#  'Sports vehicles including bicycles',
#  'State motor vehicle registration and license fees',
#  'Stationery',
#  'Sugar and sugar substitutes',
#  'Sugar and sweets',
#  'Tax return preparation and other accounting fees',
#  'Technical and business school tuition and fees',
#  'Telephone hardware',
#  'Telephone services',
#  'Televisions',
#  "Tenants' and household insurance",
#  'Tires',
#  'Tobacco and smoking products',
#  'Tobacco products other than cigarettes',
#  'Tomatoes',
#  'Tools',
#  'Toys',
#  'Transportation',
#  'Transportation commodities less motor fuel',
#  'Transportation services',
#  'Tuition',
#  'Uncooked beef roasts',
#  'Uncooked beef steaks',
#  'Uncooked ground beef',
#  'Uncooked other beef and veal',
#  'Used cars and trucks',
#  'Utilities and public transportation',
#  'Utility (piped) gas service',
#  'Vehicle accessories other than tires',
#  'Vehicle parts and equipment other than tires',
#  'Veterinarian services',
#  'Video and audio',
#  'Video and audio products',
#  'Video and audio services',
#  'Video discs and other media',
#  'Video game hardware',
#  'Watches',
#  'Water and sewer and trash collection services',
#  'Water and sewerage maintenance',
#  'Whiskey at home',
#  'White bread',
#  'Window and floor coverings and other linens',
#  'Window coverings',
#  'Wine at home',
#  'Wine away from home',
#  'Wireless telephone services',
#  "Women's and girls' apparel",
#  "Women's apparel",
#  "Women's dresses",
#  "Women's footwear",
#  "Women's outerwear",
#  "Women's suits and separates",
#  "Women's underwear"}

# %% [markdown]
# ### 7778 items are not seasonally adjusted; 318 items are seasonally adjusted.

# %%
series_df['seasonal'].unique()
series_df.groupby('seasonal').count()
# Out:
# array(['S', 'U'], dtype=object)
#           series_id  area_code  item_code  periodicity_code  base_code  \
# seasonal
# S               318        318        318               318        318
# U              7778       7778       7778              7778       7778
#
#           base_period  series_title  footnote_codes  begin_year  begin_period  \
# seasonal
# S                 318           318               0         318           318
# U                7778          7778               0        7778          7778
#
#           end_year  end_period
# seasonal
# S              318         318
# U             7778        7778

# %% [markdown]
# ### There doesn't seem to be a clear trend regarding what types of items are calculated seasonally or not.

# %%
set(series_df[series_df['seasonal'] == 'S']['series_title'])
# Out:
# {'Admission to movies, theaters, and concerts in U.S. city average, all urban consumers, seasonally adjusted',
#  'Admission to sporting events in U.S. city average, all urban consumers, seasonally adjusted',
#  'Admissions in U.S. city average, all urban consumers, seasonally adjusted',
#  'Airline fares in U.S. city average, all urban consumers, seasonally adjusted',
#  'Alcoholic beverages at home in U.S. city average, all urban consumers, seasonally adjusted',
#  'Alcoholic beverages away from home in U.S. city average, all urban consumers, seasonally adjusted',
#  'Alcoholic beverages in U.S. city average, all urban consumers, seasonally adjusted',
#  'All items  less medical care in U.S. city average, all urban consumers, seasonally adjusted',
#  'All items in U.S. city average, all urban consumers, seasonally adjusted',
#  'All items less energy in U.S. city average, all urban consumers, seasonally adjusted',
#  'All items less food and energy in U.S. city average, all urban consumers, seasonally adjusted',
#  'All items less food and shelter in U.S. city average, all urban consumers, seasonally adjusted',
#  'All items less food in U.S. city average, all urban consumers, seasonally adjusted',
#  'All items less food, shelter, and energy in U.S. city average, all urban consumers, seasonally adjusted',
#  'All items less food, shelter, energy, and used cars and trucks in U.S. city average, all urban consumers, seasonally adjusted',
#  'All items less shelter in U.S. city average, all urban consumers, seasonally adjusted',
#  'Apparel in U.S. city average, all urban consumers, seasonally adjusted',
#  'Apparel less footwear in U.S. city average, all urban consumers, seasonally adjusted',
#  'Apples in U.S. city average, all urban consumers, seasonally adjusted',
#  'Appliances in U.S. city average, all urban consumers, seasonally adjusted',
#  'Audio equipment in U.S. city average, all urban consumers, seasonally adjusted',
#  'Bacon and related products in U.S. city average, all urban consumers, seasonally adjusted',
#  'Bacon, breakfast sausage, and related products in U.S. city average, all urban consumers, seasonally adjusted',
#  'Bakery products in U.S. city average, all urban consumers, seasonally adjusted',
#  'Bananas in U.S. city average, all urban consumers, seasonally adjusted',
#  'Beef and veal in U.S. city average, all urban consumers, seasonally adjusted',
#  'Beer, ale, and other malt beverages at home in U.S. city average, all urban consumers, seasonally adjusted',
#  'Beverage materials including coffee and tea in U.S. city average, all urban consumers, seasonally adjusted',
#  "Boys' and girls' footwear in U.S. city average, all urban consumers, seasonally adjusted",
#  "Boys' apparel in U.S. city average, all urban consumers, seasonally adjusted",
#  'Bread in U.S. city average, all urban consumers, seasonally adjusted',
#  'Breakfast cereal in U.S. city average, all urban consumers, seasonally adjusted',
#  'Breakfast sausage and related products in U.S. city average, all urban consumers, seasonally adjusted',
#  'Butter and margarine in U.S. city average, all urban consumers, seasonally adjusted',
#  'Butter in U.S. city average, all urban consumers, seasonally adjusted',
#  'Cable and satellite television service in U.S. city average, all urban consumers, seasonally adjusted',
#  'Cakes, cupcakes, and cookies in U.S. city average, all urban consumers, seasonally adjusted',
#  'Canned fruits and vegetables in U.S. city average, all urban consumers, seasonally adjusted',
#  'Canned fruits in U.S. city average, all urban consumers, seasonally adjusted',
#  'Canned vegetables in U.S. city average, all urban consumers, seasonally adjusted',
#  'Car and truck rental in U.S. city average, all urban consumers, seasonally adjusted',
#  'Carbonated drinks in U.S. city average, all urban consumers, seasonally adjusted',
#  'Cereals and bakery products in U.S. city average, all urban consumers, seasonally adjusted',
#  'Cereals and cereal products in U.S. city average, all urban consumers, seasonally adjusted',
#  'Cheese and related products in U.S. city average, all urban consumers, seasonally adjusted',
#  'Chicken in U.S. city average, all urban consumers, seasonally adjusted',
#  'Child care and nursery school in U.S. city average, all urban consumers, seasonally adjusted',
#  'Cigarettes in U.S. city average, all urban consumers, seasonally adjusted',
#  'Citrus fruits in U.S. city average, all urban consumers, seasonally adjusted',
#  'Club membership for shopping clubs, fraternal, or other organizations, or participant sports fees in U.S. city average, all urban consumers, seasonally adjusted',
#  'Coffee in U.S. city average, all urban consumers, seasonally adjusted',
#  'College tuition and fees in U.S. city average, all urban consumers, seasonally adjusted',
#  'Commodities in U.S. city average, all urban consumers, seasonally adjusted',
#  'Commodities less food and beverages in U.S. city average, all urban consumers, seasonally adjusted',
#  'Commodities less food and energy commodities in U.S. city average, all urban consumers, seasonally adjusted',
#  'Commodities less food in U.S. city average, all urban consumers, seasonally adjusted',
#  'Commodities less food, energy, and used cars and trucks in U.S. city average, all urban consumers, seasonally adjusted',
#  'Communication in U.S. city average, all urban consumers, seasonally adjusted',
#  'Cookies in U.S. city average, all urban consumers, seasonally adjusted',
#  'Crackers, bread, and cracker products in U.S. city average, all urban consumers, seasonally adjusted',
#  'Dairy and related products in U.S. city average, all urban consumers, seasonally adjusted',
#  'Delivery services in U.S. city average, all urban consumers, seasonally adjusted',
#  'Dental services in U.S. city average, all urban consumers, seasonally adjusted',
#  'Distilled spirits at home in U.S. city average, all urban consumers, seasonally adjusted',
#  'Distilled spirits away from home in U.S. city average, all urban consumers, seasonally adjusted',
#  'Distilled spirits, excluding whiskey, at home in U.S. city average, all urban consumers, seasonally adjusted',
#  'Domestically produced farm food in U.S. city average, all urban consumers, seasonally adjusted',
#  'Durables in U.S. city average, all urban consumers, seasonally adjusted',
#  'Education and communication commodities in U.S. city average, all urban consumers, seasonally adjusted',
#  'Education and communication in U.S. city average, all urban consumers, seasonally adjusted',
#  'Education and communication services in U.S. city average, all urban consumers, seasonally adjusted',
#  'Education in U.S. city average, all urban consumers, seasonally adjusted',
#  'Educational books and supplies in U.S. city average, all urban consumers, seasonally adjusted',
#  'Eggs in U.S. city average, all urban consumers, seasonally adjusted',
#  'Electricity in U.S. city average, all urban consumers, seasonally adjusted',
#  'Elementary and high school tuition and fees in U.S. city average, all urban consumers, seasonally adjusted',
#  'Energy commodities in U.S. city average, all urban consumers, seasonally adjusted',
#  'Energy in U.S. city average, all urban consumers, seasonally adjusted',
#  'Energy services in U.S. city average, all urban consumers, seasonally adjusted',
#  'Eyeglasses and eye care in U.S. city average, all urban consumers, seasonally adjusted',
#  'Fats and oils in U.S. city average, all urban consumers, seasonally adjusted',
#  'Fees for lessons or instructions in U.S. city average, all urban consumers, seasonally adjusted',
#  'Financial services in U.S. city average, all urban consumers, seasonally adjusted',
#  'Fish and seafood in U.S. city average, all urban consumers, seasonally adjusted',
#  'Flour and prepared flour mixes in U.S. city average, all urban consumers, seasonally adjusted',
#  'Food and beverages in U.S. city average, all urban consumers, seasonally adjusted',
#  'Food at elementary and secondary schools in U.S. city average, all urban consumers, seasonally adjusted',
#  'Food at employee sites and schools in U.S. city average, all urban consumers, seasonally adjusted',
#  'Food at home in U.S. city average, all urban consumers, seasonally adjusted',
#  'Food away from home in U.S. city average, all urban consumers, seasonally adjusted',
#  'Food in U.S. city average, all urban consumers, seasonally adjusted',
#  'Footwear in U.S. city average, all urban consumers, seasonally adjusted',
#  'Frankfurters in U.S. city average, all urban consumers, seasonally adjusted',
#  'Fresh biscuits, rolls, muffins in U.S. city average, all urban consumers, seasonally adjusted',
#  'Fresh fish and seafood in U.S. city average, all urban consumers, seasonally adjusted',
#  'Fresh fruits and vegetables in U.S. city average, all urban consumers, seasonally adjusted',
#  'Fresh fruits in U.S. city average, all urban consumers, seasonally adjusted',
#  'Fresh milk other than whole in U.S. city average, all urban consumers, seasonally adjusted',
#  'Fresh vegetables in U.S. city average, all urban consumers, seasonally adjusted',
#  'Fresh whole chicken in U.S. city average, all urban consumers, seasonally adjusted',
#  'Fresh whole milk in U.S. city average, all urban consumers, seasonally adjusted',
#  'Frozen and freeze dried prepared foods in U.S. city average, all urban consumers, seasonally adjusted',
#  'Frozen and refrigerated bakery products, pies, tarts, turnovers in U.S. city average, all urban consumers, seasonally adjusted',
#  'Frozen fish and seafood in U.S. city average, all urban consumers, seasonally adjusted',
#  'Frozen fruits and vegetables in U.S. city average, all urban consumers, seasonally adjusted',
#  'Frozen vegetables in U.S. city average, all urban consumers, seasonally adjusted',
#  'Fruits and vegetables in U.S. city average, all urban consumers, seasonally adjusted',
#  'Fuel oil and other fuels in U.S. city average, all urban consumers, seasonally adjusted',
#  'Fuel oil in U.S. city average, all urban consumers, seasonally adjusted',
#  'Fuels and utilities in U.S. city average, all urban consumers, seasonally adjusted',
#  'Full service meals and snacks in U.S. city average, all urban consumers, seasonally adjusted',
#  'Funeral expenses in U.S. city average, all urban consumers, seasonally adjusted',
#  'Furniture and bedding in U.S. city average, all urban consumers, seasonally adjusted',
#  'Garbage and trash collection in U.S. city average, all urban consumers, seasonally adjusted',
#  'Gasoline (all types) in U.S. city average, all urban consumers, seasonally adjusted',
#  'Gasoline, unleaded midgrade in U.S. city average, all urban consumers, seasonally adjusted',
#  'Gasoline, unleaded premium in U.S. city average, all urban consumers, seasonally adjusted',
#  'Gasoline, unleaded regular in U.S. city average, all urban consumers, seasonally adjusted',
#  "Girls' apparel in U.S. city average, all urban consumers, seasonally adjusted",
#  'Ham in U.S. city average, all urban consumers, seasonally adjusted',
#  'Ham, excluding canned in U.S. city average, all urban consumers, seasonally adjusted',
#  'Hospital and related services in U.S. city average, all urban consumers, seasonally adjusted',
#  'Hospital services in U.S. city average, all urban consumers, seasonally adjusted',
#  'Household cleaning products in U.S. city average, all urban consumers, seasonally adjusted',
#  'Household energy in U.S. city average, all urban consumers, seasonally adjusted',
#  'Household furnishings and operations in U.S. city average, all urban consumers, seasonally adjusted',
#  'Household furnishings and supplies in U.S. city average, all urban consumers, seasonally adjusted',
#  'Housekeeping supplies in U.S. city average, all urban consumers, seasonally adjusted',
#  'Housing at school, excluding board in U.S. city average, all urban consumers, seasonally adjusted',
#  'Housing in U.S. city average, all urban consumers, seasonally adjusted',
#  'Ice cream and related products in U.S. city average, all urban consumers, seasonally adjusted',
#  'Indoor plants and flowers in U.S. city average, all urban consumers, seasonally adjusted',
#  "Infants' and toddlers' apparel in U.S. city average, all urban consumers, seasonally adjusted",
#  'Information and information processing in U.S. city average, all urban consumers, seasonally adjusted',
#  'Information technology commodities in U.S. city average, all urban consumers, seasonally adjusted',
#  'Information technology, hardware and services in U.S. city average, all urban consumers, seasonally adjusted',
#  'Inpatient hospital services in U.S. city average, all urban consumers, seasonally adjusted',
#  'Intercity train fare in U.S. city average, all urban consumers, seasonally adjusted',
#  'Internet services and electronic information providers in U.S. city average, all urban consumers, seasonally adjusted',
#  'Jewelry and watches in U.S. city average, all urban consumers, seasonally adjusted',
#  'Jewelry in U.S. city average, all urban consumers, seasonally adjusted',
#  'Juices and nonalcoholic drinks in U.S. city average, all urban consumers, seasonally adjusted',
#  'Laundry and dry cleaning services in U.S. city average, all urban consumers, seasonally adjusted',
#  'Laundry equipment in U.S. city average, all urban consumers, seasonally adjusted',
#  'Leased cars and trucks in U.S. city average, all urban consumers, seasonally adjusted',
#  'Legal services in U.S. city average, all urban consumers, seasonally adjusted',
#  'Lettuce in U.S. city average, all urban consumers, seasonally adjusted',
#  'Lodging away from home in U.S. city average, all urban consumers, seasonally adjusted',
#  'Lunchmeats in U.S. city average, all urban consumers, seasonally adjusted',
#  'Major appliances in U.S. city average, all urban consumers, seasonally adjusted',
#  'Margarine in U.S. city average, all urban consumers, seasonally adjusted',
#  'Meats in U.S. city average, all urban consumers, seasonally adjusted',
#  'Meats, poultry, and fish in U.S. city average, all urban consumers, seasonally adjusted',
#  'Meats, poultry, fish, and eggs in U.S. city average, all urban consumers, seasonally adjusted',
#  'Medical care commodities in U.S. city average, all urban consumers, seasonally adjusted',
#  'Medical care in U.S. city average, all urban consumers, seasonally adjusted',
#  'Medical care services in U.S. city average, all urban consumers, seasonally adjusted',
#  'Medicinal drugs in U.S. city average, all urban consumers, seasonally adjusted',
#  "Men's and boys' apparel in U.S. city average, all urban consumers, seasonally adjusted",
#  "Men's apparel in U.S. city average, all urban consumers, seasonally adjusted",
#  "Men's footwear in U.S. city average, all urban consumers, seasonally adjusted",
#  "Men's furnishings in U.S. city average, all urban consumers, seasonally adjusted",
#  "Men's pants and shorts in U.S. city average, all urban consumers, seasonally adjusted",
#  "Men's shirts and sweaters in U.S. city average, all urban consumers, seasonally adjusted",
#  "Men's suits, sport coats, and outerwear in U.S. city average, all urban consumers, seasonally adjusted",
#  'Milk in U.S. city average, all urban consumers, seasonally adjusted',
#  'Miscellaneous household products in U.S. city average, all urban consumers, seasonally adjusted',
#  'Miscellaneous personal goods in U.S. city average, all urban consumers, seasonally adjusted',
#  'Miscellaneous personal services in U.S. city average, all urban consumers, seasonally adjusted',
#  'Motor fuel in U.S. city average, all urban consumers, seasonally adjusted',
#  'Motor vehicle insurance in U.S. city average, all urban consumers, seasonally adjusted',
#  'Motor vehicle maintenance and repair in U.S. city average, all urban consumers, seasonally adjusted',
#  'Motor vehicle parts and equipment in U.S. city average, all urban consumers, seasonally adjusted',
#  'Motor vehicle repair in U.S. city average, all urban consumers, seasonally adjusted',
#  'Moving, storage, freight expense in U.S. city average, all urban consumers, seasonally adjusted',
#  'Music instruments and accessories in U.S. city average, all urban consumers, seasonally adjusted',
#  'New and used motor vehicles in U.S. city average, all urban consumers, seasonally adjusted',
#  'New cars and trucks in U.S. city average, all urban consumers, seasonally adjusted',
#  'New cars in U.S. city average, all urban consumers, seasonally adjusted',
#  'New motorcycles in U.S. city average, all urban consumers, seasonally adjusted',
#  'New trucks in U.S. city average, all urban consumers, seasonally adjusted',
#  'New vehicles in U.S. city average, all urban consumers, seasonally adjusted',
#  'Nonalcoholic beverages and beverage materials in U.S. city average, all urban consumers, seasonally adjusted',
#  'Nondurables in U.S. city average, all urban consumers, seasonally adjusted',
#  'Nondurables less food and apparel in U.S. city average, all urban consumers, seasonally adjusted',
#  'Nondurables less food and beverages in U.S. city average, all urban consumers, seasonally adjusted',
#  'Nondurables less food in U.S. city average, all urban consumers, seasonally adjusted',
#  'Nondurables less food, beverages, and apparel in U.S. city average, all urban consumers, seasonally adjusted',
#  'Nonelectric cookware and tableware in U.S. city average, all urban consumers, seasonally adjusted',
#  'Nonfrozen noncarbonated juices and drinks in U.S. city average, all urban consumers, seasonally adjusted',
#  'Nursing homes and adult day services in U.S. city average, all urban consumers, seasonally adjusted',
#  'Oranges, including tangerines in U.S. city average, all urban consumers, seasonally adjusted',
#  'Other appliances in U.S. city average, all urban consumers, seasonally adjusted',
#  'Other bakery products in U.S. city average, all urban consumers, seasonally adjusted',
#  'Other beverage materials including tea in U.S. city average, all urban consumers, seasonally adjusted',
#  'Other condiments in U.S. city average, all urban consumers, seasonally adjusted',
#  'Other dairy and related products in U.S. city average, all urban consumers, seasonally adjusted',
#  'Other fats and oils including peanut butter in U.S. city average, all urban consumers, seasonally adjusted',
#  'Other food at home in U.S. city average, all urban consumers, seasonally adjusted',
#  'Other food away from home in U.S. city average, all urban consumers, seasonally adjusted',
#  'Other foods in U.S. city average, all urban consumers, seasonally adjusted',
#  'Other fresh fruits in U.S. city average, all urban consumers, seasonally adjusted',
#  'Other fresh vegetables in U.S. city average, all urban consumers, seasonally adjusted',
#  'Other furniture in U.S. city average, all urban consumers, seasonally adjusted',
#  'Other goods and services in U.S. city average, all urban consumers, seasonally adjusted',
#  'Other goods in U.S. city average, all urban consumers, seasonally adjusted',
#  'Other household equipment and furnishings in U.S. city average, all urban consumers, seasonally adjusted',
#  'Other intercity transportation in U.S. city average, all urban consumers, seasonally adjusted',
#  'Other lodging away from home including hotels and motels in U.S. city average, all urban consumers, seasonally adjusted',
#  'Other meats in U.S. city average, all urban consumers, seasonally adjusted',
#  'Other miscellaneous foods in U.S. city average, all urban consumers, seasonally adjusted',
#  'Other motor fuels in U.S. city average, all urban consumers, seasonally adjusted',
#  'Other pork including roasts, steaks, and ribs in U.S. city average, all urban consumers, seasonally adjusted',
#  'Other processed fruits and vegetables including dried in U.S. city average, all urban consumers, seasonally adjusted',
#  'Other recreation services in U.S. city average, all urban consumers, seasonally adjusted',
#  'Other recreational goods in U.S. city average, all urban consumers, seasonally adjusted',
#  'Other services in U.S. city average, all urban consumers, seasonally adjusted',
#  'Other sweets in U.S. city average, all urban consumers, seasonally adjusted',
#  'Other uncooked poultry including turkey in U.S. city average, all urban consumers, seasonally adjusted',
#  'Other video equipment in U.S. city average, all urban consumers, seasonally adjusted',
#  'Outdoor equipment and supplies in U.S. city average, all urban consumers, seasonally adjusted',
#  'Outpatient hospital services in U.S. city average, all urban consumers, seasonally adjusted',
#  "Owners' equivalent rent of primary residence in U.S. city average, all urban consumers, seasonally adjusted",
#  "Owners' equivalent rent of residences in U.S. city average, all urban consumers, seasonally adjusted",
#  'Parking and other fees in U.S. city average, all urban consumers, seasonally adjusted',
#  'Parking fees and tolls in U.S. city average, all urban consumers, seasonally adjusted',
#  'Personal care in U.S. city average, all urban consumers, seasonally adjusted',
#  'Personal computers and peripheral equipment in U.S. city average, all urban consumers, seasonally adjusted',
#  'Pet food in U.S. city average, all urban consumers, seasonally adjusted',
#  'Pet services in U.S. city average, all urban consumers, seasonally adjusted',
#  'Pet services including veterinary in U.S. city average, all urban consumers, seasonally adjusted',
#  'Pets and pet products in U.S. city average, all urban consumers, seasonally adjusted',
#  'Pets, pet products and services in U.S. city average, all urban consumers, seasonally adjusted',
#  'Photographic equipment and supplies in U.S. city average, all urban consumers, seasonally adjusted',
#  'Photographic equipment in U.S. city average, all urban consumers, seasonally adjusted',
#  'Photography in U.S. city average, all urban consumers, seasonally adjusted',
#  "Physicians' services in U.S. city average, all urban consumers, seasonally adjusted",
#  'Pork chops in U.S. city average, all urban consumers, seasonally adjusted',
#  'Pork in U.S. city average, all urban consumers, seasonally adjusted',
#  'Postage and delivery services in U.S. city average, all urban consumers, seasonally adjusted',
#  'Postage in U.S. city average, all urban consumers, seasonally adjusted',
#  'Potatoes in U.S. city average, all urban consumers, seasonally adjusted',
#  'Poultry in U.S. city average, all urban consumers, seasonally adjusted',
#  'Prepared salads in U.S. city average, all urban consumers, seasonally adjusted',
#  'Prescription drugs in U.S. city average, all urban consumers, seasonally adjusted',
#  'Private transportation in U.S. city average, all urban consumers, seasonally adjusted',
#  'Processed fish and seafood in U.S. city average, all urban consumers, seasonally adjusted',
#  'Processed fruits and vegetables in U.S. city average, all urban consumers, seasonally adjusted',
#  'Professional services in U.S. city average, all urban consumers, seasonally adjusted',
#  'Propane, kerosene, and firewood in U.S. city average, all urban consumers, seasonally adjusted',
#  'Public transportation in U.S. city average, all urban consumers, seasonally adjusted',
#  'Purchase of pets, pet supplies, accessories in U.S. city average, all urban consumers, seasonally adjusted',
#  'Recreation commodities in U.S. city average, all urban consumers, seasonally adjusted',
#  'Recreation in U.S. city average, all urban consumers, seasonally adjusted',
#  'Recreation services in U.S. city average, all urban consumers, seasonally adjusted',
#  'Recreational reading materials in U.S. city average, all urban consumers, seasonally adjusted',
#  'Rent of primary residence in U.S. city average, all urban consumers, seasonally adjusted',
#  'Rent of shelter in U.S. city average, all urban consumers, seasonally adjusted',
#  'Rice, pasta, cornmeal in U.S. city average, all urban consumers, seasonally adjusted',
#  'Roasted coffee in U.S. city average, all urban consumers, seasonally adjusted',
#  'Salad dressing in U.S. city average, all urban consumers, seasonally adjusted',
#  'Salt and other seasonings and spices in U.S. city average, all urban consumers, seasonally adjusted',
#  'Sauces and gravies in U.S. city average, all urban consumers, seasonally adjusted',
#  'Services by other medical professionals in U.S. city average, all urban consumers, seasonally adjusted',
#  'Services in U.S. city average, all urban consumers, seasonally adjusted',
#  'Services less energy services in U.S. city average, all urban consumers, seasonally adjusted',
#  'Services less medical care services in U.S. city average, all urban consumers, seasonally adjusted',
#  'Services less rent of shelter in U.S. city average, all urban consumers, seasonally adjusted',
#  'Sewing machines, fabric and supplies in U.S. city average, all urban consumers, seasonally adjusted',
#  'Shelf stable fish and seafood in U.S. city average, all urban consumers, seasonally adjusted',
#  'Shelter in U.S. city average, all urban consumers, seasonally adjusted',
#  'Ship fare in U.S. city average, all urban consumers, seasonally adjusted',
#  'Snacks in U.S. city average, all urban consumers, seasonally adjusted',
#  'Soups in U.S. city average, all urban consumers, seasonally adjusted',
#  'Spices, seasonings, condiments, sauces in U.S. city average, all urban consumers, seasonally adjusted',
#  'Sporting goods in U.S. city average, all urban consumers, seasonally adjusted',
#  'Sports equipment in U.S. city average, all urban consumers, seasonally adjusted',
#  'Sports vehicles including bicycles in U.S. city average, all urban consumers, seasonally adjusted',
#  'Stationery, stationery supplies, gift wrap in U.S. city average, all urban consumers, seasonally adjusted',
#  'Sugar and artificial sweeteners in U.S. city average, all urban consumers, seasonally adjusted',
#  'Sugar and sweets in U.S. city average, all urban consumers, seasonally adjusted',
#  'Tax return preparation and other accounting fees in U.S. city average, all urban consumers, seasonally adjusted',
#  'Technical and business school tuition and fees in U.S. city average, all urban consumers, seasonally adjusted',
#  'Telephone hardware, calculators, and other consumer information items in U.S. city average, all urban consumers, seasonally adjusted',
#  'Televisions in U.S. city average, all urban consumers, seasonally adjusted',
#  'Tires in U.S. city average, all urban consumers, seasonally adjusted',
#  'Tobacco and smoking products in U.S. city average, all urban consumers, seasonally adjusted',
#  'Tomatoes in U.S. city average, all urban consumers, seasonally adjusted',
#  'Tools, hardware, outdoor equipment and supplies in U.S. city average, all urban consumers, seasonally adjusted',
#  'Toys in U.S. city average, all urban consumers, seasonally adjusted',
#  'Toys, games, hobbies and playground equipment in U.S. city average, all urban consumers, seasonally adjusted',
#  'Transportation commodities less motor fuel in U.S. city average, all urban consumers, seasonally adjusted',
#  'Transportation in U.S. city average, all urban consumers, seasonally adjusted',
#  'Transportation services in U.S. city average, all urban consumers, seasonally adjusted',
#  'Tuition, other school fees, and childcare in U.S. city average, all urban consumers, seasonally adjusted',
#  'Uncooked beef steaks in U.S. city average, all urban consumers, seasonally adjusted',
#  'Uncooked ground beef in U.S. city average, all urban consumers, seasonally adjusted',
#  'Used cars and trucks in U.S. city average, all urban consumers, seasonally adjusted',
#  'Utilities and public transportation in U.S. city average, all urban consumers, seasonally adjusted',
#  'Utility (piped) gas service in U.S. city average, all urban consumers, seasonally adjusted',
#  'Veterinarian services in U.S. city average, all urban consumers, seasonally adjusted',
#  'Video and audio in U.S. city average, all urban consumers, seasonally adjusted',
#  'Video and audio products in U.S. city average, all urban consumers, seasonally adjusted',
#  'Video and audio services in U.S. city average, all urban consumers, seasonally adjusted',
#  'Watches in U.S. city average, all urban consumers, seasonally adjusted',
#  'Water and sewer and trash collection services in U.S. city average, all urban consumers, seasonally adjusted',
#  'Water and sewerage maintenance in U.S. city average, all urban consumers, seasonally adjusted',
#  'Whiskey at home in U.S. city average, all urban consumers, seasonally adjusted',
#  'Window and floor coverings and other linens in U.S. city average, all urban consumers, seasonally adjusted',
#  'Window coverings in U.S. city average, all urban consumers, seasonally adjusted',
#  'Wine at home in U.S. city average, all urban consumers, seasonally adjusted',
#  "Women's and girls' apparel in U.S. city average, all urban consumers, seasonally adjusted",
#  "Women's apparel in U.S. city average, all urban consumers, seasonally adjusted",
#  "Women's dresses in U.S. city average, all urban consumers, seasonally adjusted",
#  "Women's footwear in U.S. city average, all urban consumers, seasonally adjusted",
#  "Women's outerwear in U.S. city average, all urban consumers, seasonally adjusted",
#  "Women's suits and separates in U.S. city average, all urban consumers, seasonally adjusted",
#  "Women's underwear, nightwear, sportswear and accessories in U.S. city average, all urban consumers, seasonally adjusted"}

# %%
set(series_df[series_df['seasonal'] == 'U']['series_title'])
# Out:
# {'Energy services in Midwest - Size Class D, all urban consumers, not seasonally adjusted',
#  'Commodities in Washington-Baltimore, DC-MD-VA-WV, all urban consumers, not seasonally adjusted',
#  'Toys, games, hobbies and playground equipment in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Alcoholic beverages in Mountain, all urban consumers, not seasonally adjusted',
#  'Transportation in Riverside-San Bernardino-Ontario, CA, all urban consumers, not seasonally adjusted',
#  'Motor vehicle insurance in Riverside-San Bernardino-Ontario, CA, all urban consumers, not seasonally adjusted',
#  'Apparel in South - Size Class D, all urban consumers, not seasonally adjusted',
#  'All items in Size Class B/C, all urban consumers, not seasonally adjusted',
#  'Gasoline, unleaded regular in Pacific, all urban consumers, not seasonally adjusted',
#  'Dairy and related products in Northeast - Size Class B/C, all urban consumers, not seasonally adjusted',
#  'Commodities in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Pet services including veterinary in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Fruits and vegetables in Chicago-Naperville-Elgin, IL-IN-WI, all urban consumers, not seasonally adjusted',
#  'Rent of primary residence in Midwest urban, all urban consumers, not seasonally adjusted',
#  'Education and communication in Northeast - Size Class A, all urban consumers, not seasonally adjusted',
#  'Other recreational goods in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Nonalcoholic beverages and beverage materials in West North Central, all urban consumers, not seasonally adjusted',
#  "Owners' equivalent rent of primary residence in Size Class D (under 50,000), all urban consumers, not seasonally adjusted",
#  "Women's suits and separates in U.S. city average, all urban consumers, not seasonally adjusted",
#  'Commodities less food in New England, all urban consumers, not seasonally adjusted',
#  'Education and communication commodities in West North Central, all urban consumers, not seasonally adjusted',
#  'Nondurables less food and beverages in Baltimore-Columbia-Towson, MD, all urban consumers, not seasonally adjusted',
#  'Commodities less food in Midwest - Size Class D, all urban consumers, not seasonally adjusted',
#  'All items less food and energy in Milwaukee-Racine, WI, all urban consumers, not seasonally adjusted',
#  'Services less medical care services in South Atlantic, all urban consumers, not seasonally adjusted',
#  'All items less food in Size Class A, all urban consumers, not seasonally adjusted',
#  'Commodities in Phoenix-Mesa-Scottsdale, AZ, all urban consumers, not seasonally adjusted',
#  'Gasoline (all types) in Size Class A, all urban consumers, not seasonally adjusted',
#  'Food away from home in South - Size Class D, all urban consumers, not seasonally adjusted',
#  'Other goods in Midwest - Size Class D, all urban consumers, not seasonally adjusted',
#  'Fuels and utilities in Midwest - Size Class A, all urban consumers, not seasonally adjusted',
#  'New and used motor vehicles in West South Central, all urban consumers, not seasonally adjusted',
#  'Gasoline (all types) in Cincinnati-Hamilton, OH-KY-IN, all urban consumers, not seasonally adjusted',
#  'Energy commodities in Size Class A, all urban consumers, not seasonally adjusted',
#  'Housing in Seattle-Tacoma-Bellevue, WA, all urban consumers, not seasonally adjusted',
#  'Fruits and vegetables in West North Central, all urban consumers, not seasonally adjusted',
#  'All items - old base in Northeast - Size Class A, all urban consumers, not seasonally adjusted',
#  'Gas (piped) and electricity in Dallas-Fort Worth-Arlington, TX, all urban consumers, not seasonally adjusted',
#  'Fuels and utilities in Seattle-Tacoma-Bellevue, WA, all urban consumers, not seasonally adjusted',
#  'Dairy and related products in St. Louis, MO-IL, all urban consumers, not seasonally adjusted',
#  'All items less shelter in Middle Atlantic, all urban consumers, not seasonally adjusted',
#  'Other goods in West - Size Class B/C, all urban consumers, not seasonally adjusted',
#  'All items less food and energy in West - Size Class A, all urban consumers, not seasonally adjusted',
#  'Services in West - Size Class B/C, all urban consumers, not seasonally adjusted',
#  'Transportation in East North Central, all urban consumers, not seasonally adjusted',
#  'Other goods and services in New York-Newark-Jersey City, NY-NJ-PA, all urban consumers, not seasonally adjusted',
#  'Rent of primary residence in West - Size Class A, all urban consumers, not seasonally adjusted',
#  'Gasoline, unleaded regular in West North Central, all urban consumers, not seasonally adjusted',
#  'Household furnishings and supplies in Midwest - Size Class A, all urban consumers, not seasonally adjusted',
#  'Cereals and cereal products in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Services in Dallas-Fort Worth-Arlington, TX, all urban consumers, not seasonally adjusted',
#  'Commodities less food and beverages in Portland-Salem, OR-WA, all urban consumers, not seasonally adjusted',
#  'Shelter in Portland-Salem, OR-WA, all urban consumers, not seasonally adjusted',
#  'Food at home in Portland-Salem, OR-WA, all urban consumers, not seasonally adjusted',
#  'Gasoline, unleaded premium in Portland-Salem, OR-WA, all urban consumers, not seasonally adjusted',
#  'Other goods and services in San Francisco-Oakland-Hayward, CA, all urban consumers, not seasonally adjusted',
#  'Motor vehicle insurance in Dallas-Fort Worth-Arlington, TX, all urban consumers, not seasonally adjusted',
#  'Motor vehicle insurance in New York-Newark-Jersey City, NY-NJ-PA, all urban consumers, not seasonally adjusted',
#  'Education and communication commodities in Riverside-San Bernardino-Ontario, CA, all urban consumers, not seasonally adjusted',
#  'Intercity bus fare in U.S. city average, all urban consumers, not seasonally adjusted',
#  'All items less medical care in New England, all urban consumers, not seasonally adjusted',
#  'Education and communication commodities in Middle Atlantic, all urban consumers, not seasonally adjusted',
#  'Household furnishings and supplies in West urban, all urban consumers, not seasonally adjusted',
#  'Fruits and vegetables in Size Class A, all urban consumers, not seasonally adjusted',
#  'Fresh fruits in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Transportation commodities less motor fuel in Boston-Cambridge-Newton, MA-NH, all urban consumers, not seasonally adjusted',
#  'Services in Urban Alaska, all urban consumers, not seasonally adjusted',
#  'Gasoline, unleaded midgrade in Pacific, all urban consumers, not seasonally adjusted',
#  'Jewelry and watches in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Transportation in Washington-Arlington-Alexandria, DC-VA-MD-WV, all urban consumers, not seasonally adjusted',
#  'Other goods and services in Riverside-San Bernardino-Ontario, CA, all urban consumers, not seasonally adjusted',
#  'Processed fruits and vegetables in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Food away from home in East South Central, all urban consumers, not seasonally adjusted',
#  'Gasoline (all types) in South - Size Class A, all urban consumers, not seasonally adjusted',
#  'Private transportation in Baltimore-Columbia-Towson, MD, all urban consumers, not seasonally adjusted',
#  'All items less shelter in Los Angeles-Long Beach-Anaheim, CA, all urban consumers, not seasonally adjusted',
#  'Cereals and bakery products in Chicago-Naperville-Elgin, IL-IN-WI, all urban consumers, not seasonally adjusted',
#  'Apparel in Minneapolis-St.Paul-Bloomington, MN-WI, all urban consumers, not seasonally adjusted',
#  'Rent of primary residence in South - Size Class A, all urban consumers, not seasonally adjusted',
#  'New and used motor vehicles in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Gasoline, unleaded midgrade in Middle Atlantic, all urban consumers, not seasonally adjusted',
#  'All items in Washington-Baltimore, DC-MD-VA-WV, all urban consumers, not seasonally adjusted',
#  'Energy services in Size Class D (under 50,000), all urban consumers, not seasonally adjusted',
#  'Education and communication in Midwest - Size Class D, all urban consumers, not seasonally adjusted',
#  'Other personal services in South - Size Class A, all urban consumers, not seasonally adjusted',
#  'Food in Atlanta-Sandy Springs-Roswell, GA, all urban consumers, not seasonally adjusted',
#  'Private transportation in Chicago-Naperville-Elgin, IL-IN-WI, all urban consumers, not seasonally adjusted',
#  'Commodities in South - Size Class B/C, all urban consumers, not seasonally adjusted',
#  'New and used motor vehicles in New England, all urban consumers, not seasonally adjusted',
#  'Nondurables less food and beverages in Size Class A, all urban consumers, not seasonally adjusted',
#  'Household energy in Minneapolis-St.Paul-Bloomington, MN-WI, all urban consumers, not seasonally adjusted',
#  'All items - old base in Washington-Arlington-Alexandria, DC-VA-MD-WV, all urban consumers, not seasonally adjusted',
#  'Education and communication services in Washington-Arlington-Alexandria, DC-VA-MD-WV, all urban consumers, not seasonally adjusted',
#  'Private transportation in San Diego-Carlsbad, CA, all urban consumers, not seasonally adjusted',
#  'Other goods and services in Urban Hawaii, all urban consumers, not seasonally adjusted',
#  'Other food at home in Los Angeles-Long Beach-Anaheim, CA, all urban consumers, not seasonally adjusted',
#  'Gasoline, unleaded premium in South urban, all urban consumers, not seasonally adjusted',
#  'Household energy in South - Size Class B/C, all urban consumers, not seasonally adjusted',
#  'Frozen noncarbonated juices and drinks in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Alcoholic beverages in Middle Atlantic, all urban consumers, not seasonally adjusted',
#  'Nondurables less food and beverages in Northeast - Size Class A, all urban consumers, not seasonally adjusted',
#  'Services in Los Angeles-Long Beach-Anaheim, CA, all urban consumers, not seasonally adjusted',
#  'Education and communication in Philadelphia-Camden-Wilmington, PA-NJ-DE-MD, all urban consumers, not seasonally adjusted',
#  'Meats, poultry, fish, and eggs in Atlanta-Sandy Springs-Roswell, GA, all urban consumers, not seasonally adjusted',
#  'Commodities less food and energy commodities in Northeast urban, all urban consumers, not seasonally adjusted',
#  'Household furnishings and operations in Northeast - Size Class A, all urban consumers, not seasonally adjusted',
#  'Household energy in Baltimore-Columbia-Towson, MD, all urban consumers, not seasonally adjusted',
#  'Services less energy services in Size Class D (under 50,000), all urban consumers, not seasonally adjusted',
#  'Energy in St. Louis, MO-IL, all urban consumers, not seasonally adjusted',
#  'Transportation commodities less motor fuel in South - Size Class B/C, all urban consumers, not seasonally adjusted',
#  'All items less shelter in Washington-Arlington-Alexandria, DC-VA-MD-WV, all urban consumers, not seasonally adjusted',
#  'Education and communication commodities in Cincinnati-Hamilton, OH-KY-IN, all urban consumers, not seasonally adjusted',
#  'Nonalcoholic beverages and beverage materials in Los Angeles-Long Beach-Anaheim, CA, all urban consumers, not seasonally adjusted',
#  'Cereals and bakery products in Middle Atlantic, all urban consumers, not seasonally adjusted',
#  'Motor fuel in Tampa-St. Petersburg-Clearwater, FL, all urban consumers, not seasonally adjusted',
#  'Transportation in Los Angeles-Riverside-Orange County, CA, all urban consumers, not seasonally adjusted',
#  'Motor fuel in Middle Atlantic, all urban consumers, not seasonally adjusted',
#  'Household furnishings and operations in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Medical care services in South urban, all urban consumers, not seasonally adjusted',
#  'Services in South urban, all urban consumers, not seasonally adjusted',
#  'Motor vehicle insurance in Size Class B/C, all urban consumers, not seasonally adjusted',
#  'Nondurables in Size Class A, all urban consumers, not seasonally adjusted',
#  'Private transportation in Philadelphia-Camden-Wilmington, PA-NJ-DE-MD, all urban consumers, not seasonally adjusted',
#  'Other personal services in St. Louis, MO-IL, all urban consumers, not seasonally adjusted',
#  'Services less medical care services in Cincinnati-Hamilton, OH-KY-IN, all urban consumers, not seasonally adjusted',
#  'Electricity in West urban, all urban consumers, not seasonally adjusted',
#  'Household furnishings and operations in Pacific, all urban consumers, not seasonally adjusted',
#  'Commodities in New York-Newark-Jersey City, NY-NJ-PA, all urban consumers, not seasonally adjusted',
#  'Transportation in Portland-Salem, OR-WA, all urban consumers, not seasonally adjusted',
#  'Food away from home in Midwest urban, all urban consumers, not seasonally adjusted',
#  'Education and communication commodities in Washington-Baltimore, DC-MD-VA-WV, all urban consumers, not seasonally adjusted',
#  'Commodities in St. Louis, MO-IL, all urban consumers, not seasonally adjusted',
#  'New vehicles in Chicago-Naperville-Elgin, IL-IN-WI, all urban consumers, not seasonally adjusted',
#  'Commodities in Baltimore-Columbia-Towson, MD, all urban consumers, not seasonally adjusted',
#  'Utility (piped) gas service in Size Class D (under 50,000), all urban consumers, not seasonally adjusted',
#  'Other personal services in Los Angeles-Long Beach-Anaheim, CA, all urban consumers, not seasonally adjusted',
#  'Household energy in Northeast urban, all urban consumers, not seasonally adjusted',
#  'Fuels and utilities in Philadelphia-Camden-Wilmington, PA-NJ-DE-MD, all urban consumers, not seasonally adjusted',
#  'Nondurables less food in Boston-Cambridge-Newton, MA-NH, all urban consumers, not seasonally adjusted',
#  'Tuition, other school fees, and childcare in Chicago-Naperville-Elgin, IL-IN-WI, all urban consumers, not seasonally adjusted',
#  'Energy in Pacific, all urban consumers, not seasonally adjusted',
#  'Cereals and bakery products in Denver-Aurora-Lakewood, CO, all urban consumers, not seasonally adjusted',
#  'Private transportation in Midwest urban, all urban consumers, not seasonally adjusted',
#  'Other goods in Northeast - Size Class B/C, all urban consumers, not seasonally adjusted',
#  'Transportation in Phoenix-Mesa-Scottsdale, AZ, all urban consumers, not seasonally adjusted',
#  'Gasoline (all types) in West - Size Class A, all urban consumers, not seasonally adjusted',
#  'Club membership for shopping clubs, fraternal, or other organizations, or participant sports fees in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Food at home in Tampa-St. Petersburg-Clearwater, FL, all urban consumers, not seasonally adjusted',
#  'Energy services in Pittsburgh, PA, all urban consumers, not seasonally adjusted',
#  'Household energy in Riverside-San Bernardino-Ontario, CA, all urban consumers, not seasonally adjusted',
#  'Meats, poultry, fish, and eggs in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Nondurables less food and beverages in Midwest urban, all urban consumers, not seasonally adjusted',
#  'All items less shelter in Mountain, all urban consumers, not seasonally adjusted',
#  'Gasoline (all types) in Portland-Salem, OR-WA, all urban consumers, not seasonally adjusted',
#  'Motor fuel in Seattle-Tacoma-Bellevue, WA, all urban consumers, not seasonally adjusted',
#  'Motor vehicle insurance in Mountain, all urban consumers, not seasonally adjusted',
#  'Electricity in Atlanta-Sandy Springs-Roswell, GA, all urban consumers, not seasonally adjusted',
#  'Tuition, other school fees, and childcare in South Atlantic, all urban consumers, not seasonally adjusted',
#  'Services less medical care services in Midwest urban, all urban consumers, not seasonally adjusted',
#  'Food at home in Washington-Baltimore, DC-MD-VA-WV, all urban consumers, not seasonally adjusted',
#  'Medical care in Northeast - Size Class B/C, all urban consumers, not seasonally adjusted',
#  'Nondurables less food and beverages in Philadelphia-Camden-Wilmington, PA-NJ-DE-MD, all urban consumers, not seasonally adjusted',
#  'Commodities less food and beverages in Seattle-Tacoma-Bellevue, WA, all urban consumers, not seasonally adjusted',
#  'Education and communication commodities in Portland-Salem, OR-WA, all urban consumers, not seasonally adjusted',
#  'Tuition, other school fees, and childcare in New York-Newark-Jersey City, NY-NJ-PA, all urban consumers, not seasonally adjusted',
#  'Fruits and vegetables in Seattle-Tacoma-Bellevue, WA, all urban consumers, not seasonally adjusted',
#  'Fruits and vegetables in East South Central, all urban consumers, not seasonally adjusted',
#  'Recreation services in South urban, all urban consumers, not seasonally adjusted',
#  'Other goods in Boston-Cambridge-Newton, MA-NH, all urban consumers, not seasonally adjusted',
#  'Nondurables less food in New York-Newark-Jersey City, NY-NJ-PA, all urban consumers, not seasonally adjusted',
#  'Used cars and trucks in West urban, all urban consumers, not seasonally adjusted',
#  'Services less medical care services in Detroit-Warren-Dearborn, MI, all urban consumers, not seasonally adjusted',
#  'Nondurables less food and beverages in St. Louis, MO-IL, all urban consumers, not seasonally adjusted',
#  'Shelter in Baltimore-Columbia-Towson, MD, all urban consumers, not seasonally adjusted',
#  'All items in South - Size Class D, all urban consumers, not seasonally adjusted',
#  'Transportation commodities less motor fuel in Detroit-Warren-Dearborn, MI, all urban consumers, not seasonally adjusted',
#  'Food and beverages in Urban Hawaii, all urban consumers, not seasonally adjusted',
#  'Food away from home in Tampa-St. Petersburg-Clearwater, FL, all urban consumers, not seasonally adjusted',
#  'Car and truck rental in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Gasoline, unleaded premium in Urban Hawaii, all urban consumers, not seasonally adjusted',
#  'Dairy and related products in West North Central, all urban consumers, not seasonally adjusted',
#  'Apparel in Portland-Salem, OR-WA, all urban consumers, not seasonally adjusted',
#  'New cars and trucks in Northeast urban, all urban consumers, not seasonally adjusted',
#  'Commodities less food and beverages in South Atlantic, all urban consumers, not seasonally adjusted',
#  'Rent of primary residence in New England, all urban consumers, not seasonally adjusted',
#  'Food at home in South Atlantic, all urban consumers, not seasonally adjusted',
#  'Durables in Midwest - Size Class D, all urban consumers, not seasonally adjusted',
#  'Energy services in West urban, all urban consumers, not seasonally adjusted',
#  'Food away from home in Midwest - Size Class B/C, all urban consumers, not seasonally adjusted',
#  'Alcoholic beverages in Midwest - Size Class D, all urban consumers, not seasonally adjusted',
#  'Tuition, other school fees, and childcare in Size Class A, all urban consumers, not seasonally adjusted',
#  'Services less medical care services in Chicago-Naperville-Elgin, IL-IN-WI, all urban consumers, not seasonally adjusted',
#  'Food in Washington-Arlington-Alexandria, DC-VA-MD-WV, all urban consumers, not seasonally adjusted',
#  'Recreation in East North Central, all urban consumers, not seasonally adjusted',
#  'Food at home in Miami-Fort Lauderdale-West Palm Beach, FL, all urban consumers, not seasonally adjusted',
#  "Men's furnishings in U.S. city average, all urban consumers, not seasonally adjusted",
#  'Commodities less food and beverages in New England, all urban consumers, not seasonally adjusted',
#  'Gasoline, unleaded premium in Pittsburgh, PA, all urban consumers, not seasonally adjusted',
#  'Education and communication in San Francisco-Oakland-Hayward, CA, all urban consumers, not seasonally adjusted',
#  'Food and beverages in Tampa-St. Petersburg-Clearwater, FL, all urban consumers, not seasonally adjusted',
#  'Dairy and related products in South - Size Class A, all urban consumers, not seasonally adjusted',
#  'Medical care commodities in Size Class B/C, all urban consumers, not seasonally adjusted',
#  'Gasoline, unleaded regular in Pittsburgh, PA, all urban consumers, not seasonally adjusted',
#  'All items in San Diego-Carlsbad, CA, all urban consumers, not seasonally adjusted',
#  'Other goods in Midwest - Size Class A, all urban consumers, not seasonally adjusted',
#  'Dairy and related products in New England, all urban consumers, not seasonally adjusted',
#  'Commodities less food and beverages in West South Central, all urban consumers, not seasonally adjusted',
#  'All items less food and energy in Miami-Fort Lauderdale-West Palm Beach, FL, all urban consumers, not seasonally adjusted',
#  'Education and communication in Dallas-Fort Worth-Arlington, TX, all urban consumers, not seasonally adjusted',
#  'Nondurables less food and beverages in Seattle-Tacoma-Bellevue, WA, all urban consumers, not seasonally adjusted',
#  'Apparel in Middle Atlantic, all urban consumers, not seasonally adjusted',
#  'Private transportation in Urban Alaska, all urban consumers, not seasonally adjusted',
#  'Housing in New York-Newark-Jersey City, NY-NJ-PA, all urban consumers, not seasonally adjusted',
#  'Bread in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Transportation commodities less motor fuel in St. Louis, MO-IL, all urban consumers, not seasonally adjusted',
#  'Peanut butter in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Commodities in Milwaukee-Racine, WI, all urban consumers, not seasonally adjusted',
#  'Utility (piped) gas service in Miami-Fort Lauderdale-West Palm Beach, FL, all urban consumers, not seasonally adjusted',
#  'Commodities less food in Urban Hawaii, all urban consumers, not seasonally adjusted',
#  'Motor vehicle insurance in West - Size Class A, all urban consumers, not seasonally adjusted',
#  'Other goods and services in St. Louis, MO-IL, all urban consumers, not seasonally adjusted',
#  'Household energy in Phoenix-Mesa-Scottsdale, AZ, all urban consumers, not seasonally adjusted',
#  'Nondurables less food in South Atlantic, all urban consumers, not seasonally adjusted',
#  'Fruits and vegetables in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Meats, poultry, fish, and eggs in South urban, all urban consumers, not seasonally adjusted',
#  'Gasoline, unleaded midgrade in Midwest urban, all urban consumers, not seasonally adjusted',
#  'Commodities less food and beverages in East North Central, all urban consumers, not seasonally adjusted',
#  'Electricity in Size Class D (under 50,000), all urban consumers, not seasonally adjusted',
#  'Services less medical care services in Northeast - Size Class B/C, all urban consumers, not seasonally adjusted',
#  'New vehicles in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Durables in South Atlantic, all urban consumers, not seasonally adjusted',
#  'Gasoline, unleaded premium in Dallas-Fort Worth-Arlington, TX, all urban consumers, not seasonally adjusted',
#  'Commodities less food in West - Size Class A, all urban consumers, not seasonally adjusted',
#  'Transportation commodities less motor fuel in Urban Alaska, all urban consumers, not seasonally adjusted',
#  'All items less food, shelter, energy, and used cars and trucks in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Gasoline (all types) in East North Central, all urban consumers, not seasonally adjusted',
#  'Gasoline, unleaded regular in East North Central, all urban consumers, not seasonally adjusted',
#  'Gasoline, unleaded premium in West North Central, all urban consumers, not seasonally adjusted',
#  'Used cars and trucks in San Diego-Carlsbad, CA, all urban consumers, not seasonally adjusted',
#  "Owners' equivalent rent of primary residence in East North Central, all urban consumers, not seasonally adjusted",
#  'Transportation services in Size Class D (under 50,000), all urban consumers, not seasonally adjusted',
#  'Transportation in Philadelphia-Camden-Wilmington, PA-NJ-DE-MD, all urban consumers, not seasonally adjusted',
#  'Motor fuel in Phoenix-Mesa-Scottsdale, AZ, all urban consumers, not seasonally adjusted',
#  'Recreation in Tampa-St. Petersburg-Clearwater, FL, all urban consumers, not seasonally adjusted',
#  "Owners' equivalent rent of primary residence in West - Size Class A, all urban consumers, not seasonally adjusted",
#  'Gasoline, unleaded regular in Washington-Arlington-Alexandria, DC-VA-MD-WV, all urban consumers, not seasonally adjusted',
#  'Household furnishings and supplies in Midwest urban, all urban consumers, not seasonally adjusted',
#  'Commodities less food in West South Central, all urban consumers, not seasonally adjusted',
#  'Automobile service clubs in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Education and communication commodities in New York-Newark-Jersey City, NY-NJ-PA, all urban consumers, not seasonally adjusted',
#  'Apparel in Miami-Fort Lauderdale-West Palm Beach, FL, all urban consumers, not seasonally adjusted',
#  'Durables in Atlanta-Sandy Springs-Roswell, GA, all urban consumers, not seasonally adjusted',
#  'Housing in Denver-Aurora-Lakewood, CO, all urban consumers, not seasonally adjusted',
#  'Commodities less food in South - Size Class B/C, all urban consumers, not seasonally adjusted',
#  'Other goods and services in West - Size Class B/C, all urban consumers, not seasonally adjusted',
#  'Food in Pacific, all urban consumers, not seasonally adjusted',
#  'Services less medical care services in South - Size Class B/C, all urban consumers, not seasonally adjusted',
#  'Nondurables less food in East North Central, all urban consumers, not seasonally adjusted',
#  'All items less energy in South - Size Class D, all urban consumers, not seasonally adjusted',
#  'Household furnishings and operations in Cleveland-Akron, OH, all urban consumers, not seasonally adjusted',
#  'New cars and trucks in Size Class B/C, all urban consumers, not seasonally adjusted',
#  'Gasoline, unleaded premium in Seattle-Tacoma-Bellevue, WA, all urban consumers, not seasonally adjusted',
#  'Gasoline, unleaded midgrade in West urban, all urban consumers, not seasonally adjusted',
#  'Rent of primary residence in South Atlantic, all urban consumers, not seasonally adjusted',
#  'Education and communication services in Midwest - Size Class A, all urban consumers, not seasonally adjusted',
#  'Alcoholic beverages in Los Angeles-Riverside-Orange County, CA, all urban consumers, not seasonally adjusted',
#  'Food at home in Los Angeles-Riverside-Orange County, CA, all urban consumers, not seasonally adjusted',
#  'Other goods in Urban Alaska, all urban consumers, not seasonally adjusted',
#  'Dairy and related products in San Diego-Carlsbad, CA, all urban consumers, not seasonally adjusted',
#  'Other food at home in Size Class A, all urban consumers, not seasonally adjusted',
#  'All items less energy in South Atlantic, all urban consumers, not seasonally adjusted',
#  'Utility (piped) gas service in Houston-The Woodlands-Sugar Land, TX, all urban consumers, not seasonally adjusted',
#  'Gas (piped) and electricity in Pacific, all urban consumers, not seasonally adjusted',
#  'Food in Los Angeles-Riverside-Orange County, CA, all urban consumers, not seasonally adjusted',
#  'Services less medical care services in Seattle-Tacoma-Bellevue, WA, all urban consumers, not seasonally adjusted',
#  'Food and beverages in Dallas-Fort Worth-Arlington, TX, all urban consumers, not seasonally adjusted',
#  'Gas (piped) and electricity in Detroit-Warren-Dearborn, MI, all urban consumers, not seasonally adjusted',
#  'Gasoline, unleaded midgrade in Mountain, all urban consumers, not seasonally adjusted',
#  'Household furnishings and supplies in West - Size Class A, all urban consumers, not seasonally adjusted',
#  'Commodities in Cincinnati-Hamilton, OH-KY-IN, all urban consumers, not seasonally adjusted',
#  'All items - old base in South urban, all urban consumers, not seasonally adjusted',
#  'Other food at home in New England, all urban consumers, not seasonally adjusted',
#  'New vehicles in New England, all urban consumers, not seasonally adjusted',
#  'Utility (piped) gas service in West - Size Class B/C, all urban consumers, not seasonally adjusted',
#  'Commodities less food in South - Size Class D, all urban consumers, not seasonally adjusted',
#  'Private transportation in Riverside-San Bernardino-Ontario, CA, all urban consumers, not seasonally adjusted',
#  'Other food at home in Minneapolis-St.Paul-Bloomington, MN-WI, all urban consumers, not seasonally adjusted',
#  'Services in Washington-Baltimore, DC-MD-VA-WV, all urban consumers, not seasonally adjusted',
#  'Transportation in Middle Atlantic, all urban consumers, not seasonally adjusted',
#  'Housing in South urban, all urban consumers, not seasonally adjusted',
#  'Food in East North Central, all urban consumers, not seasonally adjusted',
#  'Utility (piped) gas service in Atlanta-Sandy Springs-Roswell, GA, all urban consumers, not seasonally adjusted',
#  'Medical care in Portland-Salem, OR-WA, all urban consumers, not seasonally adjusted',
#  'Cereals and bakery products in Midwest urban, all urban consumers, not seasonally adjusted',
#  'Gasoline (all types) in Size Class B/C, all urban consumers, not seasonally adjusted',
#  'All items less energy in South - Size Class B/C, all urban consumers, not seasonally adjusted',
#  'All items less shelter in South - Size Class B/C, all urban consumers, not seasonally adjusted',
#  'All items in Denver-Aurora-Lakewood, CO, all urban consumers, not seasonally adjusted',
#  'Private transportation in South urban, all urban consumers, not seasonally adjusted',
#  'Tuition, other school fees, and childcare in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Private transportation in South - Size Class A, all urban consumers, not seasonally adjusted',
#  'Education and communication in Cincinnati-Hamilton, OH-KY-IN, all urban consumers, not seasonally adjusted',
#  'Bananas in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Transportation in Milwaukee-Racine, WI, all urban consumers, not seasonally adjusted',
#  'Energy commodities in Size Class B/C, all urban consumers, not seasonally adjusted',
#  'Commodities in Minneapolis-St.Paul-Bloomington, MN-WI, all urban consumers, not seasonally adjusted',
#  'Electricity in Midwest - Size Class D, all urban consumers, not seasonally adjusted',
#  'Housing in San Francisco-Oakland-Hayward, CA, all urban consumers, not seasonally adjusted',
#  'Gasoline, unleaded midgrade in Kansas City, MO-KS, all urban consumers, not seasonally adjusted',
#  'All items - old base in Detroit-Warren-Dearborn, MI, all urban consumers, not seasonally adjusted',
#  'Gasoline, unleaded midgrade in Riverside-San Bernardino-Ontario, CA, all urban consumers, not seasonally adjusted',
#  'Gasoline, unleaded regular in Kansas City, MO-KS, all urban consumers, not seasonally adjusted',
#  'All items less medical care in St. Louis, MO-IL, all urban consumers, not seasonally adjusted',
#  'Education and communication commodities in Baltimore-Columbia-Towson, MD, all urban consumers, not seasonally adjusted',
#  'Transportation commodities less motor fuel in Portland-Salem, OR-WA, all urban consumers, not seasonally adjusted',
#  'Alcoholic beverages in South - Size Class D, all urban consumers, not seasonally adjusted',
#  'Services less rent of shelter in Midwest - Size Class B/C, all urban consumers, not seasonally adjusted',
#  'Nondurables in Atlanta-Sandy Springs-Roswell, GA, all urban consumers, not seasonally adjusted',
#  'Services less medical care services in Washington-Baltimore, DC-MD-VA-WV, all urban consumers, not seasonally adjusted',
#  'Household furnishings and supplies in East North Central, all urban consumers, not seasonally adjusted',
#  'Gasoline, unleaded midgrade in Size Class B/C, all urban consumers, not seasonally adjusted',
#  'Utility (piped) gas service in South - Size Class B/C, all urban consumers, not seasonally adjusted',
#  'Education and communication commodities in Philadelphia-Camden-Wilmington, PA-NJ-DE-MD, all urban consumers, not seasonally adjusted',
#  'Other goods in East South Central, all urban consumers, not seasonally adjusted',
#  'Durables in Mountain, all urban consumers, not seasonally adjusted',
#  'Electricity in South - Size Class B/C, all urban consumers, not seasonally adjusted',
#  'Meats in U.S. city average, all urban consumers, not seasonally adjusted',
#  "Owners' equivalent rent of residences in Minneapolis-St.Paul-Bloomington, MN-WI, all urban consumers, not seasonally adjusted",
#  'Household furnishings and supplies in Chicago-Naperville-Elgin, IL-IN-WI, all urban consumers, not seasonally adjusted',
#  'Citrus fruits in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Motor vehicle insurance in Denver-Aurora-Lakewood, CO, all urban consumers, not seasonally adjusted',
#  'Services in Size Class B/C, all urban consumers, not seasonally adjusted',
#  'Private transportation in Miami-Fort Lauderdale-West Palm Beach, FL, all urban consumers, not seasonally adjusted',
#  'Used cars and trucks in East South Central, all urban consumers, not seasonally adjusted',
#  'Gasoline (all types) in Pittsburgh, PA, all urban consumers, not seasonally adjusted',
#  'Sporting goods in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Dairy and related products in Boston-Cambridge-Newton, MA-NH, all urban consumers, not seasonally adjusted',
#  "Owners' equivalent rent of primary residence in Midwest - Size Class A, all urban consumers, not seasonally adjusted",
#  'All items less energy in Northeast - Size Class B/C, all urban consumers, not seasonally adjusted',
#  'Intracity mass transit in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Food away from home in Detroit-Warren-Dearborn, MI, all urban consumers, not seasonally adjusted',
#  'All items less food and energy in Urban Alaska, all urban consumers, not seasonally adjusted',
#  'Energy services in Milwaukee-Racine, WI, all urban consumers, not seasonally adjusted',
#  'All items less energy in West North Central, all urban consumers, not seasonally adjusted',
#  'Transportation commodities less motor fuel in Minneapolis-St.Paul-Bloomington, MN-WI, all urban consumers, not seasonally adjusted',
#  'Other goods in Cincinnati-Hamilton, OH-KY-IN, all urban consumers, not seasonally adjusted',
#  'Tax return preparation and other accounting fees in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Apparel in Urban Alaska, all urban consumers, not seasonally adjusted',
#  'Other goods and services in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Services less medical care services in New York-Newark-Jersey City, NY-NJ-PA, all urban consumers, not seasonally adjusted',
#  'Transportation in San Diego-Carlsbad, CA, all urban consumers, not seasonally adjusted',
#  'Services less rent of shelter in West - Size Class A, all urban consumers, not seasonally adjusted',
#  'Nonalcoholic beverages and beverage materials in Boston-Cambridge-Newton, MA-NH, all urban consumers, not seasonally adjusted',
#  'Rent of primary residence in Miami-Fort Lauderdale-West Palm Beach, FL, all urban consumers, not seasonally adjusted',
#  'Recreation in Boston-Cambridge-Newton, MA-NH, all urban consumers, not seasonally adjusted',
#  'Rice, pasta, cornmeal in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Nondurables less food in Mountain, all urban consumers, not seasonally adjusted',
#  'Gasoline, unleaded premium in East South Central, all urban consumers, not seasonally adjusted',
#  'Fuels and utilities in San Diego-Carlsbad, CA, all urban consumers, not seasonally adjusted',
#  'Apparel in Midwest - Size Class A, all urban consumers, not seasonally adjusted',
#  'Gasoline (all types) in St. Louis, MO-IL, all urban consumers, not seasonally adjusted',
#  'Nondurables less food in South - Size Class A, all urban consumers, not seasonally adjusted',
#  'All items less food and energy in Dallas-Fort Worth-Arlington, TX, all urban consumers, not seasonally adjusted',
#  'Utility (piped) gas service in South urban, all urban consumers, not seasonally adjusted',
#  "Owners' equivalent rent of primary residence in Midwest - Size Class B/C, all urban consumers, not seasonally adjusted",
#  'Rent of primary residence in West - Size Class B/C, all urban consumers, not seasonally adjusted',
#  'Gasoline, unleaded midgrade in Minneapolis-St.Paul-Bloomington, MN-WI, all urban consumers, not seasonally adjusted',
#  'New cars in Size Class D (under 50,000), all urban consumers, not seasonally adjusted',
#  'Household furnishings and operations in Size Class D (under 50,000), all urban consumers, not seasonally adjusted',
#  'Transportation in Denver-Aurora-Lakewood, CO, all urban consumers, not seasonally adjusted',
#  'Sports equipment in U.S. city average, all urban consumers, not seasonally adjusted',
#  'All items less food and energy in Size Class B/C, all urban consumers, not seasonally adjusted',
#  "Owners' equivalent rent of primary residence in Kansas City, MO-KS, all urban consumers, not seasonally adjusted",
#  'Gasoline, unleaded midgrade in Midwest - Size Class A, all urban consumers, not seasonally adjusted',
#  'Alcoholic beverages at home in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Nondurables in Los Angeles-Riverside-Orange County, CA, all urban consumers, not seasonally adjusted',
#  'Meats, poultry, fish, and eggs in West - Size Class A, all urban consumers, not seasonally adjusted',
#  'Nondurables less food in New England, all urban consumers, not seasonally adjusted',
#  'Household furnishings and supplies in Urban Alaska, all urban consumers, not seasonally adjusted',
#  'Sports vehicles including bicycles in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Other personal services in San Diego-Carlsbad, CA, all urban consumers, not seasonally adjusted',
#  'Nondurables less food, beverages, and apparel in South urban, all urban consumers, not seasonally adjusted',
#  'All items less food and energy in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Services less rent of shelter in South - Size Class D, all urban consumers, not seasonally adjusted',
#  'Household energy in Midwest - Size Class D, all urban consumers, not seasonally adjusted',
#  "Owners' equivalent rent of primary residence in Phoenix-Mesa-Scottsdale, AZ, all urban consumers, not seasonally adjusted",
#  'All items less food and energy in Portland-Salem, OR-WA, all urban consumers, not seasonally adjusted',
#  'Household furnishings and supplies in Mountain, all urban consumers, not seasonally adjusted',
#  'Recreation in Urban Alaska, all urban consumers, not seasonally adjusted',
#  'Nondurables less food in West - Size Class B/C, all urban consumers, not seasonally adjusted',
#  "Women's underwear, nightwear, sportswear and accessories in U.S. city average, all urban consumers, not seasonally adjusted",
#  'All items in South Atlantic, all urban consumers, not seasonally adjusted',
#  'Apparel in East North Central, all urban consumers, not seasonally adjusted',
#  'Nondurables in South - Size Class B/C, all urban consumers, not seasonally adjusted',
#  'Gasoline, unleaded premium in West urban, all urban consumers, not seasonally adjusted',
#  'Household energy in West - Size Class A, all urban consumers, not seasonally adjusted',
#  'Household energy in Atlanta-Sandy Springs-Roswell, GA, all urban consumers, not seasonally adjusted',
#  'Durables in Tampa-St. Petersburg-Clearwater, FL, all urban consumers, not seasonally adjusted',
#  'Other goods and services in Detroit-Warren-Dearborn, MI, all urban consumers, not seasonally adjusted',
#  'Nondurables in Denver-Aurora-Lakewood, CO, all urban consumers, not seasonally adjusted',
#  'Private transportation in Mountain, all urban consumers, not seasonally adjusted',
#  'Fuel oil and other fuels in U.S. city average, all urban consumers, not seasonally adjusted',
#  'All items less medical care in West South Central, all urban consumers, not seasonally adjusted',
#  'Video and audio in U.S. city average, all urban consumers, not seasonally adjusted',
#  'All items less energy in Phoenix-Mesa-Scottsdale, AZ, all urban consumers, not seasonally adjusted',
#  'Housing in Mountain, all urban consumers, not seasonally adjusted',
#  'Services less rent of shelter in Chicago-Naperville-Elgin, IL-IN-WI, all urban consumers, not seasonally adjusted',
#  'Nonalcoholic beverages and beverage materials in East South Central, all urban consumers, not seasonally adjusted',
#  "Owners' equivalent rent of primary residence in Washington-Baltimore, DC-MD-VA-WV, all urban consumers, not seasonally adjusted",
#  'Durables in St. Louis, MO-IL, all urban consumers, not seasonally adjusted',
#  'All items in Boston-Cambridge-Newton, MA-NH, all urban consumers, not seasonally adjusted',
#  'Household furnishings and supplies in Baltimore-Columbia-Towson, MD, all urban consumers, not seasonally adjusted',
#  'Utility (piped) gas service in San Diego-Carlsbad, CA, all urban consumers, not seasonally adjusted',
#  'Sauces and gravies in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Transportation in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Gasoline, unleaded premium in San Francisco-Oakland-Hayward, CA, all urban consumers, not seasonally adjusted',
#  'Other food at home in St. Louis, MO-IL, all urban consumers, not seasonally adjusted',
#  'Used cars and trucks in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Transportation in New England, all urban consumers, not seasonally adjusted',
#  'Household furnishings and supplies in U.S. city average, all urban consumers, not seasonally adjusted',
#  'New and used motor vehicles in West urban, all urban consumers, not seasonally adjusted',
#  'Nondurables less food in Philadelphia-Camden-Wilmington, PA-NJ-DE-MD, all urban consumers, not seasonally adjusted',
#  'New and used motor vehicles in Dallas-Fort Worth-Arlington, TX, all urban consumers, not seasonally adjusted',
#  'Nondurables in Washington-Baltimore, DC-MD-VA-WV, all urban consumers, not seasonally adjusted',
#  'Energy in Chicago-Naperville-Elgin, IL-IN-WI, all urban consumers, not seasonally adjusted',
#  'Shelter in Denver-Aurora-Lakewood, CO, all urban consumers, not seasonally adjusted',
#  'Apparel in South urban, all urban consumers, not seasonally adjusted',
#  'Vehicle accessories other than tires in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Nondurables less food in Size Class D (under 50,000), all urban consumers, not seasonally adjusted',
#  'Gas (piped) and electricity in West - Size Class A, all urban consumers, not seasonally adjusted',
#  'Education and communication services in South Atlantic, all urban consumers, not seasonally adjusted',
#  'Recreation in Atlanta-Sandy Springs-Roswell, GA, all urban consumers, not seasonally adjusted',
#  'Food at home in Urban Hawaii, all urban consumers, not seasonally adjusted',
#  'Nonalcoholic beverages and beverage materials in South urban, all urban consumers, not seasonally adjusted',
#  'All items less medical care in Denver-Aurora-Lakewood, CO, all urban consumers, not seasonally adjusted',
#  'Food and beverages in Middle Atlantic, all urban consumers, not seasonally adjusted',
#  'Education and communication services in New York-Newark-Jersey City, NY-NJ-PA, all urban consumers, not seasonally adjusted',
#  'All items less food and energy in South - Size Class B/C, all urban consumers, not seasonally adjusted',
#  'All items less shelter in West South Central, all urban consumers, not seasonally adjusted',
#  'Tuition, other school fees, and childcare in Size Class B/C, all urban consumers, not seasonally adjusted',
#  'Commodities in South - Size Class D, all urban consumers, not seasonally adjusted',
#  'All items less food and energy in Riverside-San Bernardino-Ontario, CA, all urban consumers, not seasonally adjusted',
#  'Education and communication in St. Louis, MO-IL, all urban consumers, not seasonally adjusted',
#  'Medical care in Detroit-Warren-Dearborn, MI, all urban consumers, not seasonally adjusted',
#  'Motor fuel in South Atlantic, all urban consumers, not seasonally adjusted',
#  'All items - old base in Tampa-St. Petersburg-Clearwater, FL, all urban consumers, not seasonally adjusted',
#  'Services in Houston-The Woodlands-Sugar Land, TX, all urban consumers, not seasonally adjusted',
#  'Commodities less food and beverages in Urban Alaska, all urban consumers, not seasonally adjusted',
#  'Food and beverages in New England, all urban consumers, not seasonally adjusted',
#  'Food in Midwest urban, all urban consumers, not seasonally adjusted',
#  'Apparel in East South Central, all urban consumers, not seasonally adjusted',
#  'Nondurables less food in Baltimore-Columbia-Towson, MD, all urban consumers, not seasonally adjusted',
#  "Owners' equivalent rent of primary residence in South urban, all urban consumers, not seasonally adjusted",
#  'Professional services in West urban, all urban consumers, not seasonally adjusted',
#  'Medical care in Minneapolis-St.Paul-Bloomington, MN-WI, all urban consumers, not seasonally adjusted',
#  'Education and communication commodities in West urban, all urban consumers, not seasonally adjusted',
#  'Household paper products in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Other goods and services in Dallas-Fort Worth-Arlington, TX, all urban consumers, not seasonally adjusted',
#  'Other goods in Milwaukee-Racine, WI, all urban consumers, not seasonally adjusted',
#  'Nondurables less food in Washington-Arlington-Alexandria, DC-VA-MD-WV, all urban consumers, not seasonally adjusted',
#  'Food and beverages in Pacific, all urban consumers, not seasonally adjusted',
#  'All items - old base in Seattle-Tacoma-Bellevue, WA, all urban consumers, not seasonally adjusted',
#  'Household furnishings and operations in Atlanta-Sandy Springs-Roswell, GA, all urban consumers, not seasonally adjusted',
#  'Transportation commodities less motor fuel in Los Angeles-Riverside-Orange County, CA, all urban consumers, not seasonally adjusted',
#  'Education and communication in Boston-Cambridge-Newton, MA-NH, all urban consumers, not seasonally adjusted',
#  'Commodities in South - Size Class A, all urban consumers, not seasonally adjusted',
#  'Cereals and bakery products in Pacific, all urban consumers, not seasonally adjusted',
#  'Rent of shelter in Size Class A, all urban consumers, not seasonally adjusted',
#  'Pork chops in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Motor vehicle insurance in Size Class A, all urban consumers, not seasonally adjusted',
#  'Gas (piped) and electricity in New England, all urban consumers, not seasonally adjusted',
#  'Recreation in Riverside-San Bernardino-Ontario, CA, all urban consumers, not seasonally adjusted',
#  'Other goods and services in South Atlantic, all urban consumers, not seasonally adjusted',
#  'Nondurables less food in Houston-The Woodlands-Sugar Land, TX, all urban consumers, not seasonally adjusted',
#  'Apparel in Midwest - Size Class B/C, all urban consumers, not seasonally adjusted',
#  'All items - old base in Miami-Fort Lauderdale-West Palm Beach, FL, all urban consumers, not seasonally adjusted',
#  'All items - old base in Midwest - Size Class A, all urban consumers, not seasonally adjusted',
#  'Nondurables less food in Midwest - Size Class D, all urban consumers, not seasonally adjusted',
#  'All items less energy in Portland-Salem, OR-WA, all urban consumers, not seasonally adjusted',
#  "Owners' equivalent rent of residences in Mountain, all urban consumers, not seasonally adjusted",
# ...
#  'Motor vehicle insurance in South - Size Class B/C, all urban consumers, not seasonally adjusted',
#  'Nondurables less food in West North Central, all urban consumers, not seasonally adjusted',
#  'All items less medical care in East North Central, all urban consumers, not seasonally adjusted',
#  'Recorded music and music subscriptions in U.S. city average, all urban consumers, not seasonally adjusted',
#  "Owners' equivalent rent of primary residence in Mountain, all urban consumers, not seasonally adjusted",
#  'Other personal services in Midwest urban, all urban consumers, not seasonally adjusted',
#  'Durables in East South Central, all urban consumers, not seasonally adjusted',
#  'Shelter in Urban Hawaii, all urban consumers, not seasonally adjusted',
#  'Energy services in Cleveland-Akron, OH, all urban consumers, not seasonally adjusted',
#  'Nonalcoholic beverages and beverage materials in South - Size Class B/C, all urban consumers, not seasonally adjusted',
#  'Gasoline, unleaded premium in New England, all urban consumers, not seasonally adjusted',
#  'Other personal services in Denver-Aurora-Lakewood, CO, all urban consumers, not seasonally adjusted',
#  'Other services in Northeast urban, all urban consumers, not seasonally adjusted',
#  'Motor vehicle insurance in San Francisco-Oakland-Hayward, CA, all urban consumers, not seasonally adjusted',
#  'Household furnishings and supplies in Minneapolis-St.Paul-Bloomington, MN-WI, all urban consumers, not seasonally adjusted',
#  'Apparel in West - Size Class A, all urban consumers, not seasonally adjusted',
#  'Motor vehicle insurance in Midwest - Size Class B/C, all urban consumers, not seasonally adjusted',
#  'Information and information processing in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Transportation commodities less motor fuel in Midwest - Size Class A, all urban consumers, not seasonally adjusted',
#  'Motor fuel in East South Central, all urban consumers, not seasonally adjusted',
#  'Nondurables in Riverside-San Bernardino-Ontario, CA, all urban consumers, not seasonally adjusted',
#  'All items less energy in Northeast urban, all urban consumers, not seasonally adjusted',
#  'Shelter in Atlanta-Sandy Springs-Roswell, GA, all urban consumers, not seasonally adjusted',
#  'Transportation in Baltimore-Columbia-Towson, MD, all urban consumers, not seasonally adjusted',
#  'Education and communication services in Atlanta-Sandy Springs-Roswell, GA, all urban consumers, not seasonally adjusted',
#  'Alcoholic beverages in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Alcoholic beverages in Seattle-Tacoma-Bellevue, WA, all urban consumers, not seasonally adjusted',
#  'Rent of primary residence in South - Size Class D, all urban consumers, not seasonally adjusted',
#  'Food in Riverside-San Bernardino-Ontario, CA, all urban consumers, not seasonally adjusted',
#  'Commodities less food and beverages in Northeast - Size Class B/C, all urban consumers, not seasonally adjusted',
#  'Household furnishings and operations in South - Size Class D, all urban consumers, not seasonally adjusted',
#  'Recreation in West - Size Class B/C, all urban consumers, not seasonally adjusted',
#  'Other personal services in Boston-Cambridge-Newton, MA-NH, all urban consumers, not seasonally adjusted',
#  'Gasoline, unleaded regular in Urban Alaska, all urban consumers, not seasonally adjusted',
#  'Gasoline, unleaded premium in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Gasoline (all types) in New England, all urban consumers, not seasonally adjusted',
#  'Rent of shelter in Size Class B/C, all urban consumers, not seasonally adjusted',
#  'Food away from home in Washington-Arlington-Alexandria, DC-VA-MD-WV, all urban consumers, not seasonally adjusted',
#  'Other uncooked poultry including turkey in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Other goods and services in Middle Atlantic, all urban consumers, not seasonally adjusted',
#  'Commodities in Cleveland-Akron, OH, all urban consumers, not seasonally adjusted',
#  'Nondurables less food in Minneapolis-St.Paul-Bloomington, MN-WI, all urban consumers, not seasonally adjusted',
#  'All items less energy in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Food at home in Seattle-Tacoma-Bellevue, WA, all urban consumers, not seasonally adjusted',
#  'Used cars and trucks in Size Class A, all urban consumers, not seasonally adjusted',
#  'Services in East South Central, all urban consumers, not seasonally adjusted',
#  'Apparel in Boston-Cambridge-Newton, MA-NH, all urban consumers, not seasonally adjusted',
#  'All items less shelter in Midwest - Size Class A, all urban consumers, not seasonally adjusted',
#  'Gasoline, unleaded midgrade in South - Size Class D, all urban consumers, not seasonally adjusted',
#  'Household energy in Washington-Baltimore, DC-MD-VA-WV, all urban consumers, not seasonally adjusted',
#  'Food at home in South - Size Class D, all urban consumers, not seasonally adjusted',
#  'Private transportation in Pittsburgh, PA, all urban consumers, not seasonally adjusted',
#  'Motor fuel in Detroit-Warren-Dearborn, MI, all urban consumers, not seasonally adjusted',
#  'Alcoholic beverages in South Atlantic, all urban consumers, not seasonally adjusted',
#  'Other food at home in Size Class B/C, all urban consumers, not seasonally adjusted',
#  'Private transportation in San Francisco-Oakland-Hayward, CA, all urban consumers, not seasonally adjusted',
#  'Alcoholic beverages in Boston-Cambridge-Newton, MA-NH, all urban consumers, not seasonally adjusted',
#  'Cereals and bakery products in West - Size Class B/C, all urban consumers, not seasonally adjusted',
#  'Recreation services in Midwest urban, all urban consumers, not seasonally adjusted',
#  'Electricity in West North Central, all urban consumers, not seasonally adjusted',
#  'All items - old base in Milwaukee-Racine, WI, all urban consumers, not seasonally adjusted',
#  'Recreation in Los Angeles-Riverside-Orange County, CA, all urban consumers, not seasonally adjusted',
#  'Commodities less food and energy commodities in Size Class B/C, all urban consumers, not seasonally adjusted',
#  'Gasoline, unleaded midgrade in U.S. city average, all urban consumers, not seasonally adjusted',
#  'All items - old base in Atlanta-Sandy Springs-Roswell, GA, all urban consumers, not seasonally adjusted',
#  'Meats, poultry, fish, and eggs in San Diego-Carlsbad, CA, all urban consumers, not seasonally adjusted',
#  'Nondurables in Pittsburgh, PA, all urban consumers, not seasonally adjusted',
#  'Education in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Energy in Washington-Baltimore, DC-MD-VA-WV, all urban consumers, not seasonally adjusted',
#  'Durables in West urban, all urban consumers, not seasonally adjusted',
#  'Cereals and bakery products in Size Class B/C, all urban consumers, not seasonally adjusted',
#  'Other goods and services in West urban, all urban consumers, not seasonally adjusted',
#  'Nondurables in Size Class B/C, all urban consumers, not seasonally adjusted',
#  'Services less medical care services in Atlanta-Sandy Springs-Roswell, GA, all urban consumers, not seasonally adjusted',
#  'Services in Northeast urban, all urban consumers, not seasonally adjusted',
#  'Durables in Phoenix-Mesa-Scottsdale, AZ, all urban consumers, not seasonally adjusted',
#  'Gasoline, unleaded midgrade in West South Central, all urban consumers, not seasonally adjusted',
#  'All items less food in Size Class B/C, all urban consumers, not seasonally adjusted',
#  'All items less medical care in San Francisco-Oakland-Hayward, CA, all urban consumers, not seasonally adjusted',
#  'Crackers, bread, and cracker products in U.S. city average, all urban consumers, not seasonally adjusted',
#  'All items less food and energy in Washington-Baltimore, DC-MD-VA-WV, all urban consumers, not seasonally adjusted',
#  'Gasoline, unleaded regular in Mountain, all urban consumers, not seasonally adjusted',
#  'Education and communication in East North Central, all urban consumers, not seasonally adjusted',
#  'All items  less medical care in Portland-Salem, OR-WA, all urban consumers, not seasonally adjusted',
#  'Housing in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Tuition, other school fees, and childcare in Pacific, all urban consumers, not seasonally adjusted',
#  'Commodities less food in Size Class B/C, all urban consumers, not seasonally adjusted',
#  'Transportation in Minneapolis-St.Paul-Bloomington, MN-WI, all urban consumers, not seasonally adjusted',
#  'New and used motor vehicles in San Diego-Carlsbad, CA, all urban consumers, not seasonally adjusted',
#  'Other food at home in West - Size Class A, all urban consumers, not seasonally adjusted',
#  'Meats, poultry, fish, and eggs in West South Central, all urban consumers, not seasonally adjusted',
#  'Food away from home in Size Class A, all urban consumers, not seasonally adjusted',
#  'Gasoline (all types) in Seattle-Tacoma-Bellevue, WA, all urban consumers, not seasonally adjusted',
#  'Nondurables in West urban, all urban consumers, not seasonally adjusted',
#  'Household furnishings and supplies in Midwest - Size Class B/C, all urban consumers, not seasonally adjusted',
#  'Used cars and trucks in Mountain, all urban consumers, not seasonally adjusted',
#  'Fuels and utilities in Minneapolis-St.Paul-Bloomington, MN-WI, all urban consumers, not seasonally adjusted',
#  'Energy in Miami-Fort Lauderdale-West Palm Beach, FL, all urban consumers, not seasonally adjusted',
#  'Transportation in Cleveland-Akron, OH, all urban consumers, not seasonally adjusted',
#  'All items less food and energy in Midwest - Size Class A, all urban consumers, not seasonally adjusted',
#  'Eyeglasses and eye care in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Electricity in East South Central, all urban consumers, not seasonally adjusted',
#  'Video and audio services in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Medical care in Tampa-St. Petersburg-Clearwater, FL, all urban consumers, not seasonally adjusted',
#  'Fresh whole milk in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Private transportation in Cincinnati-Hamilton, OH-KY-IN, all urban consumers, not seasonally adjusted',
#  'Food away from home in South urban, all urban consumers, not seasonally adjusted',
#  'Nondurables less food and beverages in Washington-Arlington-Alexandria, DC-VA-MD-WV, all urban consumers, not seasonally adjusted',
#  'All items less food and energy in Los Angeles-Long Beach-Anaheim, CA, all urban consumers, not seasonally adjusted',
#  'Utility (piped) gas service in Middle Atlantic, all urban consumers, not seasonally adjusted',
#  'Durables in Size Class B/C, all urban consumers, not seasonally adjusted',
#  'Food in Midwest - Size Class D, all urban consumers, not seasonally adjusted',
#  'Repair of household items in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Ship fare in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Food at home in San Diego-Carlsbad, CA, all urban consumers, not seasonally adjusted',
#  'Recreational reading materials in U.S. city average, all urban consumers, not seasonally adjusted',
#  'All items - old base in Urban Alaska, all urban consumers, not seasonally adjusted',
#  'Transportation in West North Central, all urban consumers, not seasonally adjusted',
#  'Other goods in Size Class D (under 50,000), all urban consumers, not seasonally adjusted',
#  'Transportation services in West urban, all urban consumers, not seasonally adjusted',
#  'Meats, poultry, fish, and eggs in Detroit-Warren-Dearborn, MI, all urban consumers, not seasonally adjusted',
#  'Gasoline, unleaded midgrade in Milwaukee-Racine, WI, all urban consumers, not seasonally adjusted',
#  'Food and beverages in Cincinnati-Hamilton, OH-KY-IN, all urban consumers, not seasonally adjusted',
#  'Household energy in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Water and sewerage maintenance in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Gasoline, unleaded regular in Urban Hawaii, all urban consumers, not seasonally adjusted',
#  "Owners' equivalent rent of primary residence in Boston-Cambridge-Newton, MA-NH, all urban consumers, not seasonally adjusted",
#  "Boys' apparel in U.S. city average, all urban consumers, not seasonally adjusted",
#  'Housing in Cleveland-Akron, OH, all urban consumers, not seasonally adjusted',
#  'Durables in Northeast - Size Class A, all urban consumers, not seasonally adjusted',
#  'Nonalcoholic beverages and beverage materials in Phoenix-Mesa-Scottsdale, AZ, all urban consumers, not seasonally adjusted',
#  'Other services in Size Class A, all urban consumers, not seasonally adjusted',
#  'Cereals and bakery products in East South Central, all urban consumers, not seasonally adjusted',
#  'Cereals and bakery products in Size Class A, all urban consumers, not seasonally adjusted',
#  'Nonalcoholic beverages and beverage materials in Pacific, all urban consumers, not seasonally adjusted',
#  'Education and communication commodities in South Atlantic, all urban consumers, not seasonally adjusted',
#  'Services less rent of shelter in Northeast - Size Class A, all urban consumers, not seasonally adjusted',
#  'Nondurables in Cleveland-Akron, OH, all urban consumers, not seasonally adjusted',
#  'Commodities less food in Washington-Baltimore, DC-MD-VA-WV, all urban consumers, not seasonally adjusted',
#  'Food away from home in Atlanta-Sandy Springs-Roswell, GA, all urban consumers, not seasonally adjusted',
#  'Commodities less food and beverages in South - Size Class D, all urban consumers, not seasonally adjusted',
#  "Owners' equivalent rent of primary residence in New York-Newark-Jersey City, NY-NJ-PA, all urban consumers, not seasonally adjusted",
#  'Other personal services in Chicago-Naperville-Elgin, IL-IN-WI, all urban consumers, not seasonally adjusted',
#  'Commodities less food in Detroit-Warren-Dearborn, MI, all urban consumers, not seasonally adjusted',
#  'Other goods and services in Pacific, all urban consumers, not seasonally adjusted',
#  'Food at home in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Gasoline (all types) in Kansas City, MO-KS, all urban consumers, not seasonally adjusted',
#  'Care of invalids and elderly at home in U.S. city average, all urban consumers, not seasonally adjusted',
#  'Household energy in Washington-Arlington-Alexandria, DC-VA-MD-WV, all urban consumers, not seasonally adjusted',
#  'Tuition, other school fees, and childcare in West urban, all urban consumers, not seasonally adjusted',
#  'Household furnishings and supplies in Washington-Baltimore, DC-MD-VA-WV, all urban consumers, not seasonally adjusted',
#  'Nonalcoholic beverages and beverage materials in Denver-Aurora-Lakewood, CO, all urban consumers, not seasonally adjusted',
#  'Nondurables in New York-Newark-Jersey City, NY-NJ-PA, all urban consumers, not seasonally adjusted',
#  'Nonalcoholic beverages and beverage materials in Midwest urban, all urban consumers, not seasonally adjusted',
#  'Other goods in St. Louis, MO-IL, all urban consumers, not seasonally adjusted',
#  'Shelter in Size Class D (under 50,000), all urban consumers, not seasonally adjusted',
#  'Tuition, other school fees, and childcare in Miami-Fort Lauderdale-West Palm Beach, FL, all urban consumers, not seasonally adjusted',
#  'Education and communication services in Chicago-Naperville-Elgin, IL-IN-WI, all urban consumers, not seasonally adjusted',
#  'All items less shelter in Phoenix-Mesa-Scottsdale, AZ, all urban consumers, not seasonally adjusted',
#  "Owners' equivalent rent of residences in Seattle-Tacoma-Bellevue, WA, all urban consumers, not seasonally adjusted",
#  'Commodities in Miami-Fort Lauderdale-West Palm Beach, FL, all urban consumers, not seasonally adjusted',
#  ...}

# %% [markdown]
# ### Let's check the first and last records in the series_df, and see if they exist in the item_df and area_df ( i.e. the series_title contains the item_name from item_df and area_name from area_df ).

# %%
series_df[['series_id','series_title','item_code','area_code']].head(1)
item_df[item_df['item_code']==series_df['item_code'][0]]
area_df[area_df['area_code']==series_df['area_code'][0]]
# Out:
#            series_id                                       series_title  \
# 0  CUSR0000SA0        All items in U.S. city average, all urban cons...
#
#   item_code area_code
# 0       SA0      0000
#   item_code  item_name  display_level selectable  sort_sequence
# 2       SA0  All items              0          T              1
#   area_code          area_name  display_level selectable  sort_sequence
# 0      0000  U.S. city average              0          T              1

# %%
series_df[['series_id','series_title','item_code','area_code']].tail(1)
item_df[item_df['item_code']==series_df['item_code'][8095]]
area_df[area_df['area_code']==series_df['area_code'][8095]]
# Out:
#               series_id                                       series_title  \
# 8095  CUUSS49GSS47016    Gasoline, unleaded premium in Urban Alaska, al...
#
#      item_code area_code
# 8095   SS47016      S49G
#     item_code                   item_name  display_level selectable  \
# 370   SS47016  Gasoline, unleaded premium              4          T
#
#      sort_sequence
# 370            225
#    area_code     area_name  display_level selectable  sort_sequence
# 57      S49G  Urban Alaska              1          T             44

# %% [markdown]
# ### Because the number of uniques in the area_df and item_df is the same as the number of uniques in the area_code and item_code columns of the series_df, we could assume that there is a one-to-one correspondence of these values ( not necessarily true; e.g. the lists [1,2] and [1,3] both contain 2 unique values, but they do not share all unique values ). Are all the codes in area_df and item_df in series_df? We can verify this by the Boolean operations below:

# %%
# Are the area code values one-to-one?
set(series_df['area_code'].unique()) == set(area_df['area_code'])

# Are the item code values one-to-one?
set(series_df['item_code'].unique()) == set(item_df['item_code'])
# Out:
# True
# True

# %% [markdown]
# ### There are 434 series_id values in the series_df that are not in the cpi_df data. Let's drop these values before further analyses.

# %%
# Identify unique series_id values in each DataFrame.
cpiUniqueIDs = cpi_df['series_id'].unique()
seriesUniqueIDs = series_df['series_id'].unique()
len(cpiUniqueIDs)
len(seriesUniqueIDs)

# Create list of shared series_ids, and drop those not shared from series_df.
sharedIDs = list(set(cpiUniqueIDs).intersection(seriesUniqueIDs))
series_df = series_df[series_df['series_id'].isin(sharedIDs)]

# Verify that sets of series_id values match.
set(cpi_df['series_id'].unique()) == set(series_df['series_id'].unique())
# Out:
# 7928
# 8096
# True

# %% [markdown]
# ### Let's verify the periodicity_code, base_code, base_period, begin_year, begin_period, end_year, and end_period are already contained in the cpi_df data.

# %%
series_df['begin_year'].min()
cpi_df['year'].min()

series_df['end_year'].max()
cpi_df['year'].max()
# Out:
# 1913
# 1997
# 2022
# 2022

# %% [markdown]
# ### Unfortunately, it looks like not even the begin_year values match up, so let's just drop these columns from series_df, since there relevance to the actual data is questionable.

# %% [markdown]
# ### Let's drop all columns in series_df besides series_id, area_code, item_code, and seasonal.

# %%
series_df.columns.tolist()
# Out:
# ['series_id',
#  'area_code',
#  'item_code',
#  'seasonal',
#  'periodicity_code',
#  'base_code',
#  'base_period',
#  'series_title',
#  'footnote_codes',
#  'begin_year',
#  'begin_period',
#  'end_year',
#  'end_period']

# %%
series_df.head()
series_df = series_df.drop(labels=['periodicity_code',
                       'base_code',
                       'base_period',
                       'series_title',
                       'footnote_codes',
                       'begin_year',
                       'begin_period',
                       'end_year',
                       'end_period'],axis=1)
series_df.head()
# Out:
#            series_id area_code item_code seasonal periodicity_code base_code  \
# 0  CUSR0000SA0            0000       SA0        S                R         S
# 1  CUSR0000SA0E           0000      SA0E        S                R         S
# 2  CUSR0000SA0L1          0000     SA0L1        S                R         S
# 3  CUSR0000SA0L12         0000    SA0L12        S                R         S
# 4  CUSR0000SA0L12E        0000   SA0L12E        S                R         S
#
#    base_period                                       series_title  \
# 0  1982-84=100  All items in U.S. city average, all urban cons...
# 1  1982-84=100  Energy in U.S. city average, all urban consume...
# 2  1982-84=100  All items less food in U.S. city average, all ...
# 3  1982-84=100  All items less food and shelter in U.S. city a...
# 4  1982-84=100  All items less food, shelter, and energy in U....
#
#    footnote_codes  begin_year begin_period  end_year end_period
# 0             NaN        1947          M01      2022        M06
# 1             NaN        1957          M01      2022        M06
# 2             NaN        1947          M01      2022        M06
# 3             NaN        1967          M01      2022        M06
# 4             NaN        1967          M01      2022        M06
#            series_id area_code item_code seasonal
# 0  CUSR0000SA0            0000       SA0        S
# 1  CUSR0000SA0E           0000      SA0E        S
# 2  CUSR0000SA0L1          0000     SA0L1        S
# 3  CUSR0000SA0L12         0000    SA0L12        S
# 4  CUSR0000SA0L12E        0000   SA0L12E        S

# %% [markdown]
# ## df

# %% [markdown]
# ### Let's create a new DataFrame df that merges the series_df, cpi_df, area_df, item_df, and seasonal_df features.

# %% [markdown]
# ### First, let's merge the series_df with the area_code, item_code, and seasonal_text values from their respective DataFrames.

# %% [markdown]
# ### Merge in area_name, item_name, and seasonal_text features.

# %%
series_df.head()
series_df = pd.merge(series_df,area_df.set_index('area_code')['area_name'],on='area_code')
series_df = pd.merge(series_df,item_df.set_index('item_code')['item_name'],on='item_code')
series_df = series_df.rename(columns = {'seasonal':'seasonal_code'})
series_df = pd.merge(series_df,seasonal_df.set_index('seasonal_code')['seasonal_text'],on='seasonal_code')
series_df.head()
# Out:
#            series_id area_code item_code seasonal
# 0  CUSR0000SA0            0000       SA0        S
# 1  CUSR0000SA0E           0000      SA0E        S
# 2  CUSR0000SA0L1          0000     SA0L1        S
# 3  CUSR0000SA0L12         0000    SA0L12        S
# 4  CUSR0000SA0L12E        0000   SA0L12E        S
#            series_id area_code item_code seasonal_code          area_name  \
# 0  CUSR0000SA0            0000       SA0             S  U.S. city average
# 1  CUSR0000SA0E           0000      SA0E             S  U.S. city average
# 2  CUSR0000SA0L1          0000     SA0L1             S  U.S. city average
# 3  CUSR0000SA0L12         0000    SA0L12             S  U.S. city average
# 4  CUSR0000SA0L12E        0000   SA0L12E             S  U.S. city average
#
#                                   item_name        seasonal_text
# 0                                 All items  Seasonally Adjusted
# 1                                    Energy  Seasonally Adjusted
# 2                       All items less food  Seasonally Adjusted
# 3           All items less food and shelter  Seasonally Adjusted
# 4  All items less food, shelter, and energy  Seasonally Adjusted

# %% [markdown]
# ### Now we can drop the area_code, item_code, and seasonal_code features.

# %%
series_df.head()
series_df = series_df.drop(labels=['area_code','item_code','seasonal_code'],axis=1)
series_df.head()
# Out:
#            series_id area_code item_code seasonal_code          area_name  \
# 0  CUSR0000SA0            0000       SA0             S  U.S. city average
# 1  CUSR0000SA0E           0000      SA0E             S  U.S. city average
# 2  CUSR0000SA0L1          0000     SA0L1             S  U.S. city average
# 3  CUSR0000SA0L12         0000    SA0L12             S  U.S. city average
# 4  CUSR0000SA0L12E        0000   SA0L12E             S  U.S. city average
#
#                                   item_name        seasonal_text
# 0                                 All items  Seasonally Adjusted
# 1                                    Energy  Seasonally Adjusted
# 2                       All items less food  Seasonally Adjusted
# 3           All items less food and shelter  Seasonally Adjusted
# 4  All items less food, shelter, and energy  Seasonally Adjusted
#            series_id          area_name  \
# 0  CUSR0000SA0        U.S. city average
# 1  CUSR0000SA0E       U.S. city average
# 2  CUSR0000SA0L1      U.S. city average
# 3  CUSR0000SA0L12     U.S. city average
# 4  CUSR0000SA0L12E    U.S. city average
#
#                                   item_name        seasonal_text
# 0                                 All items  Seasonally Adjusted
# 1                                    Energy  Seasonally Adjusted
# 2                       All items less food  Seasonally Adjusted
# 3           All items less food and shelter  Seasonally Adjusted
# 4  All items less food, shelter, and energy  Seasonally Adjusted

# %% [markdown]
# ### Next, let's merge some features into the cpi_df.

# %% [markdown]
# ### First, let's drop the average period values.

# %%
cpi_df['period'].unique()
cpi_df = cpi_df[cpi_df['period'].isin(['M13','S01','S02','S03']) == False]
# Out:
# array(['M01', 'M02', 'M03', 'M04', 'M05', 'M06', 'M07', 'M08', 'M09',
#        'M10', 'M11', 'M12', 'M13', 'S01', 'S02', 'S03'], dtype=object)

# %%
# Sum is zero if values are not in period feature.
sum(cpi_df['period'].isin(['M13','S01','S02','S03']))
# Out:
# 0

# %% [markdown]
# ### Next, let's merge in the period_name feature from the period_df.

# %%
cpi_df.head()
cpi_df = pd.merge(cpi_df,period_df.set_index('period')['period_name'],on='period')
cpi_df.head()
# Out:
#            series_id  year period  value
# 0  CUSR0000SA0        1997    M01  159.4
# 1  CUSR0000SA0        1997    M02  159.7
# 2  CUSR0000SA0        1997    M03  159.8
# 3  CUSR0000SA0        1997    M04  159.9
# 4  CUSR0000SA0        1997    M05  159.9
#            series_id  year period  value period_name
# 0  CUSR0000SA0        1997    M01  159.4     January
# 1  CUSR0000SA0        1998    M01  162.0     January
# 2  CUSR0000SA0        1999    M01  164.7     January
# 3  CUSR0000SA0        2000    M01  169.3     January
# 4  CUSR0000SA0        2001    M01  175.6     January

# %% [markdown]
# ### Next, let's convert the year and period_name into a datetime object feature.

# %%
cpi_df.head()
cpi_df['date'] = pd.to_datetime(cpi_df['year'].apply(str) + cpi_df['period_name'],format='%Y%B')
cpi_df.head()
# Out:
#            series_id  year period  value period_name
# 0  CUSR0000SA0        1997    M01  159.4     January
# 1  CUSR0000SA0        1998    M01  162.0     January
# 2  CUSR0000SA0        1999    M01  164.7     January
# 3  CUSR0000SA0        2000    M01  169.3     January
# 4  CUSR0000SA0        2001    M01  175.6     January
#            series_id  year period  value period_name       date
# 0  CUSR0000SA0        1997    M01  159.4     January 1997-01-01
# 1  CUSR0000SA0        1998    M01  162.0     January 1998-01-01
# 2  CUSR0000SA0        1999    M01  164.7     January 1999-01-01
# 3  CUSR0000SA0        2000    M01  169.3     January 2000-01-01
# 4  CUSR0000SA0        2001    M01  175.6     January 2001-01-01

# %% [markdown]
# ### We can drop the year, period, and period_name features now.

# %%
cpi_df.head()
cpi_df = cpi_df.drop(['year','period','period_name'],axis=1)
cpi_df.head()
# Out:
#            series_id  year period  value period_name       date
# 0  CUSR0000SA0        1997    M01  159.4     January 1997-01-01
# 1  CUSR0000SA0        1998    M01  162.0     January 1998-01-01
# 2  CUSR0000SA0        1999    M01  164.7     January 1999-01-01
# 3  CUSR0000SA0        2000    M01  169.3     January 2000-01-01
# 4  CUSR0000SA0        2001    M01  175.6     January 2001-01-01
#            series_id  value       date
# 0  CUSR0000SA0        159.4 1997-01-01
# 1  CUSR0000SA0        162.0 1998-01-01
# 2  CUSR0000SA0        164.7 1999-01-01
# 3  CUSR0000SA0        169.3 2000-01-01
# 4  CUSR0000SA0        175.6 2001-01-01

# %% [markdown]
# ### Now, let's merge the cpi_df and series_df into one DataFrame df.

# %%
df = pd.merge(cpi_df,series_df,on='series_id')
df.head()
# Out:
#            series_id  value       date          area_name  item_name  \
# 0  CUSR0000SA0        159.4 1997-01-01  U.S. city average  All items
# 1  CUSR0000SA0        162.0 1998-01-01  U.S. city average  All items
# 2  CUSR0000SA0        164.7 1999-01-01  U.S. city average  All items
# 3  CUSR0000SA0        169.3 2000-01-01  U.S. city average  All items
# 4  CUSR0000SA0        175.6 2001-01-01  U.S. city average  All items
#
#          seasonal_text
# 0  Seasonally Adjusted
# 1  Seasonally Adjusted
# 2  Seasonally Adjusted
# 3  Seasonally Adjusted
# 4  Seasonally Adjusted

# %% [markdown]
# ### Let's drop all of the Seasonally Adjusted data, and then drop the seasonal_text column.

# %%
df = df[df['seasonal_text']=='Seasonally Adjusted']
df['seasonal_text'].unique().tolist()
df = df.drop(['seasonal_text'],axis=1)
df.head()
# Out:
# ['Seasonally Adjusted']
#            series_id  value       date          area_name  item_name
# 0  CUSR0000SA0        159.4 1997-01-01  U.S. city average  All items
# 1  CUSR0000SA0        162.0 1998-01-01  U.S. city average  All items
# 2  CUSR0000SA0        164.7 1999-01-01  U.S. city average  All items
# 3  CUSR0000SA0        169.3 2000-01-01  U.S. city average  All items
# 4  CUSR0000SA0        175.6 2001-01-01  U.S. city average  All items

# %% [markdown]
# ### We can now drop the series_id feature, and, for visual convenience, we can rename and reorder the columns ( columns ordered from left to right in increasing specificity ).

# %%
df.head()
df = df.drop(['series_id'],axis=1)
df = df.rename(columns={'area_name':'area','item_name':'item'})
df = df[['area','date','item','value']]
df.head()
# Out:
#            series_id  value       date          area_name  item_name
# 0  CUSR0000SA0        159.4 1997-01-01  U.S. city average  All items
# 1  CUSR0000SA0        162.0 1998-01-01  U.S. city average  All items
# 2  CUSR0000SA0        164.7 1999-01-01  U.S. city average  All items
# 3  CUSR0000SA0        169.3 2000-01-01  U.S. city average  All items
# 4  CUSR0000SA0        175.6 2001-01-01  U.S. city average  All items
#                 area       date       item  value
# 0  U.S. city average 1997-01-01  All items  159.4
# 1  U.S. city average 1998-01-01  All items  162.0
# 2  U.S. city average 1999-01-01  All items  164.7
# 3  U.S. city average 2000-01-01  All items  169.3
# 4  U.S. city average 2001-01-01  All items  175.6

# %% [markdown]
# # Visualizations

# %% [markdown]
# ### Let's get an idea of the various items and areas we are working with.

# %%
df.info()
df.describe().transpose()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88694 entries, 0 to 88693
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   area    88694 non-null  object
#  1   date    88694 non-null  datetime64[ns]
#  2   item    88694 non-null  object
#  3   value   88694 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 3.4+ MB
#          count        mean         std    min    25%    50%        75%  \
# value  88694.0  192.929021  108.811469  1.269  123.4  170.1  233.14775
#
#             max
# value  1346.046

# %%
df.columns
# Out:
# Index(['area', 'date', 'item', 'value'], dtype='object')

# %%
df['area'].nunique()
df['area'].unique().tolist()
# Out:
# 1
# ['U.S. city average']

# %%
df['item'].nunique()
df['item'].unique().tolist()
# Out:
# 318
# ['All items',
#  'Energy',
#  'All items less food',
#  'All items less food and shelter',
#  'All items less food, shelter, and energy',
#  'All items less food, shelter, energy, and used cars and trucks',
#  'All items less food and energy',
#  'All items less shelter',
#  'All items less medical care',
#  'All items less energy',
#  'Apparel less footwear',
#  'Apparel',
#  "Men's and boys' apparel",
#  "Women's and girls' apparel",
#  'Commodities',
#  'Energy commodities',
#  'Commodities less food',
#  'Commodities less food and beverages',
#  'Commodities less food and energy commodities',
#  'Commodities less food, energy, and used cars and trucks',
#  'Durables',
#  'Education and communication',
#  'Education',
#  'Communication',
#  'Information and information processing',
#  'Education and communication commodities',
#  'Education and communication services',
#  'Food and beverages',
#  'Food',
#  'Food at home',
#  'Cereals and bakery products',
#  'Meats, poultry, fish, and eggs',
#  'Meats, poultry, and fish',
#  'Meats',
#  'Fruits and vegetables',
#  'Fresh fruits and vegetables',
#  'Nonalcoholic beverages and beverage materials',
#  'Other food at home',
#  'Alcoholic beverages',
#  'Other goods and services',
#  'Personal care',
#  'Other goods',
#  'Housing',
#  'Shelter',
#  'Fuels and utilities',
#  'Household energy',
#  'Household furnishings and operations',
#  'Household furnishings and supplies',
#  'Medical care',
#  'Medical care commodities',
#  'Medical care services',
#  'Nondurables',
#  'Domestically produced farm food',
#  'Nondurables less food',
#  'Nondurables less food and beverages',
#  'Nondurables less food, beverages, and apparel',
#  'Nondurables less food and apparel',
#  'Recreation',
#  'Recreation commodities',
#  'Recreation services',
#  'Services',
#  'Utilities and public transportation',
#  'Rent of shelter',
#  'Other services',
#  'Transportation services',
#  'Services less rent of shelter',
#  'Services less medical care services',
#  'Services less energy services',
#  'Transportation',
#  'Private transportation',
#  'Transportation commodities less motor fuel',
#  "Men's apparel",
#  "Men's suits, sport coats, and outerwear",
#  "Men's underwear, nightwear, swimwear and accessories",
#  "Men's shirts and sweaters",
#  "Men's pants and shorts",
#  "Boys' apparel",
#  "Women's apparel",
#  "Women's outerwear",
#  "Women's dresses",
#  "Women's suits and separates",
#  "Women's underwear, nightwear, swimwear and accessories",
#  "Girls' apparel",
#  'Footwear',
#  "Men's footwear",
#  "Boys' and girls' footwear",
#  "Women's footwear",
#  "Infants' and toddlers' apparel",
#  'Jewelry and watches',
#  'Watches',
#  'Jewelry',
#  'Educational books and supplies',
#  'Tuition, other school fees, and childcare',
#  'College tuition and fees',
#  'Elementary and high school tuition and fees',
#  'Day care and preschool',
#  'Technical and business school tuition and fees',
#  'Postage and delivery services',
#  'Postage',
#  'Delivery services',
#  'Information technology, hardware and services',
#  'Computers, peripherals, and smart home assistants',
#  'Internet services and electronic information providers',
#  'Telephone hardware, calculators, and other consumer information items',
#  'Information technology commodities',
#  'Cereals and cereal products',
#  'Flour and prepared flour mixes',
#  'Breakfast cereal',
#  'Rice, pasta, cornmeal',
#  'Bakery products',
#  'Bread',
#  'Fresh biscuits, rolls, muffins',
#  'Cakes, cupcakes, and cookies',
#  'Other bakery products',
#  'Beef and veal',
#  'Uncooked ground beef',
#  'Uncooked beef steaks',
#  'Pork',
#  'Bacon, breakfast sausage, and related products',
#  'Ham',
#  'Pork chops',
#  'Other pork including roasts, steaks, and ribs',
#  'Other meats',
#  'Poultry',
#  'Chicken',
#  'Other uncooked poultry including turkey',
#  'Fish and seafood',
#  'Fresh fish and seafood',
#  'Processed fish and seafood',
#  'Eggs',
#  'Dairy and related products',
#  'Milk',
#  'Cheese and related products',
#  'Ice cream and related products',
#  'Other dairy and related products',
#  'Fresh fruits',
#  'Apples',
#  'Bananas',
#  'Citrus fruits',
#  'Other fresh fruits',
#  'Fresh vegetables',
#  'Potatoes',
#  'Lettuce',
#  'Tomatoes',
#  'Other fresh vegetables',
#  'Processed fruits and vegetables',
#  'Canned fruits and vegetables',
#  'Frozen fruits and vegetables',
#  'Other processed fruits and vegetables including dried',
#  'Juices and nonalcoholic drinks',
#  'Carbonated drinks',
#  'Nonfrozen noncarbonated juices and drinks',
#  'Beverage materials including coffee and tea',
#  'Coffee',
#  'Other beverage materials including tea',
#  'Sugar and sweets',
#  'Sugar and sugar substitutes',
#  'Other sweets',
#  'Fats and oils',
#  'Butter and margarine',
#  'Salad dressing',
#  'Other fats and oils including peanut butter',
#  'Other foods',
#  'Soups',
#  'Frozen and freeze dried prepared foods',
#  'Snacks',
#  'Spices, seasonings, condiments, sauces',
#  'Other miscellaneous foods',
#  'Food away from home',
#  'Full service meals and snacks',
#  'Food at employee sites and schools',
#  'Other food away from home',
#  'Alcoholic beverages at home',
#  'Beer, ale, and other malt beverages at home',
#  'Distilled spirits at home',
#  'Wine at home',
#  'Alcoholic beverages away from home',
#  'Tobacco and smoking products',
#  'Cigarettes',
#  'Miscellaneous personal services',
#  'Legal services',
#  'Funeral expenses',
#  'Laundry and dry cleaning services',
#  'Financial services',
#  'Miscellaneous personal goods',
#  'Rent of primary residence',
#  'Lodging away from home',
#  'Housing at school, excluding board',
#  'Other lodging away from home including hotels and motels',
#  "Owners' equivalent rent of residences",
#  "Owners' equivalent rent of primary residence",
#  'Fuel oil and other fuels',
#  'Fuel oil',
#  'Propane, kerosene, and firewood',
#  'Energy services',
#  'Electricity',
#  'Utility (piped) gas service',
#  'Water and sewer and trash collection services',
#  'Water and sewerage maintenance',
#  'Garbage and trash collection',
#  'Window and floor coverings and other linens',
#  'Window coverings',
#  'Furniture and bedding',
#  'Other furniture',
#  'Appliances',
#  'Major appliances',
#  'Other appliances',
#  'Other household equipment and furnishings',
#  'Indoor plants and flowers',
#  'Nonelectric cookware and tableware',
#  'Tools, hardware, outdoor equipment and supplies',
#  'Outdoor equipment and supplies',
#  'Housekeeping supplies',
#  'Household cleaning products',
#  'Miscellaneous household products',
#  'Moving, storage, freight expense',
#  'Professional services',
#  "Physicians' services",
#  'Dental services',
#  'Eyeglasses and eye care',
#  'Services by other medical professionals',
#  'Hospital and related services',
#  'Hospital services',
#  'Nursing homes and adult day services',
#  'Medicinal drugs',
#  'Prescription drugs',
#  'Video and audio',
#  'Televisions',
#  'Cable and satellite television service',
#  'Other video equipment',
#  'Audio equipment',
#  'Video and audio products',
#  'Video and audio services',
#  'Pets, pet products and services',
#  'Pets and pet products',
#  'Pet services including veterinary',
#  'Sporting goods',
#  'Sports vehicles including bicycles',
#  'Sports equipment',
#  'Photography',
#  'Photographic equipment and supplies',
#  'Other recreational goods',
#  'Toys',
#  'Sewing machines, fabric and supplies',
#  'Music instruments and accessories',
#  'Other recreation services',
#  'Club membership for shopping clubs, fraternal, or other organizations, or participant sports fees',
#  'Admissions',
#  'Fees for lessons or instructions',
#  'Recreational reading materials',
#  'New and used motor vehicles',
#  'New vehicles',
#  'Used cars and trucks',
#  'Leased cars and trucks',
#  'Car and truck rental',
#  'Motor fuel',
#  'Gasoline (all types)',
#  'Other motor fuels',
#  'Motor vehicle parts and equipment',
#  'Tires',
#  'Motor vehicle maintenance and repair',
#  'Motor vehicle repair',
#  'Motor vehicle insurance',
#  'Parking and other fees',
#  'Public transportation',
#  'Airline fares',
#  'Other intercity transportation',
#  'Cookies',
#  'Crackers, bread, and cracker products',
#  'Frozen and refrigerated bakery products, pies, tarts, turnovers',
#  'Bacon and related products',
#  'Breakfast sausage and related products',
#  'Ham, excluding canned',
#  'Frankfurters',
#  'Lunchmeats',
#  'Fresh whole chicken',
#  'Shelf stable fish and seafood',
#  'Frozen fish and seafood',
#  'Fresh whole milk',
#  'Fresh milk other than whole',
#  'Butter',
#  'Oranges, including tangerines',
#  'Canned fruits',
#  'Frozen vegetables',
#  'Canned vegetables',
#  'Margarine',
#  'Roasted coffee',
#  'Salt and other seasonings and spices',
#  'Sauces and gravies',
#  'Other condiments',
#  'Prepared salads',
#  'Whiskey at home',
#  'Distilled spirits, excluding whiskey, at home',
#  'Distilled spirits away from home',
#  'Laundry equipment',
#  'Stationery, stationery supplies, gift wrap',
#  'New cars',
#  'New cars and trucks',
#  'New trucks',
#  'New motorcycles',
#  'Gasoline, unleaded regular',
#  'Gasoline, unleaded midgrade',
#  'Gasoline, unleaded premium',
#  'Parking fees and tolls',
#  'Intercity train fare',
#  'Ship fare',
#  'Inpatient hospital services',
#  'Outpatient hospital services',
#  'Toys, games, hobbies and playground equipment',
#  'Photographic equipment',
#  'Pet food',
#  'Purchase of pets, pet supplies, accessories',
#  'Admission to movies, theaters, and concerts',
#  'Admission to sporting events',
#  'Pet services',
#  'Veterinarian services',
#  'Tax return preparation and other accounting fees',
#  'Food at elementary and secondary schools']

# %% [markdown]
# ### Let's create lists for the various types of locations.

# %%
cities = ['U.S. city average',
          'Pittsburgh, PA',
          'Cleveland-Akron, OH',
          'Washington-Baltimore, DC-MD-VA-WV',
          'Los Angeles-Riverside-Orange County, CA',
          'Boston-Cambridge-Newton, MA-NH',
          'New York-Newark-Jersey City, NY-NJ-PA',
          'Philadelphia-Camden-Wilmington, PA-NJ-DE-MD',
          'Chicago-Naperville-Elgin, IL-IN-WI',
          'Detroit-Warren-Dearborn, MI',
          'Minneapolis-St.Paul-Bloomington, MN-WI',
          'St. Louis, MO-IL',
          'Washington-Arlington-Alexandria, DC-VA-MD-WV',
          'Miami-Fort Lauderdale-West Palm Beach, FL',
          'Atlanta-Sandy Springs-Roswell, GA',
          'Tampa-St. Petersburg-Clearwater, FL',
          'Baltimore-Columbia-Towson, MD',
          'Dallas-Fort Worth-Arlington, TX',
          'Houston-The Woodlands-Sugar Land, TX',
          'Phoenix-Mesa-Scottsdale, AZ',
          'Denver-Aurora-Lakewood, CO',
          'Los Angeles-Long Beach-Anaheim, CA',
          'San Francisco-Oakland-Hayward, CA',
          'Riverside-San Bernardino-Ontario, CA',
          'Seattle-Tacoma-Bellevue WA',
          'San Diego-Carlsbad, CA',
          'Urban Hawaii',
          'Urban Alaska',
          'Milwaukee-Racine, WI',
          'Cincinnati-Hamilton, OH-KY-IN',
          'Kansas City, MO-KS',
          'Portland-Salem, OR-WA']

regions = ['Northeast',
           'New England',
           'Middle Atlantic',
           'Midwest',
           'East North Central',
           'West North Central',
           'South',
           'South Atlantic',
           'East South Central',
           'West South Central',
           'West',
           'Mountain',
           'Pacific']

classes = ['Size Class D',
           'Midwest - Size Class D',
           'South - Size Class D',
           'Size Class B/C',
           'Northeast - Size Class B/C',
           'Midwest - Size Class B/C',
           'South - Size Class B/C',
           'West - Size Class B/C',
           'Size Class A',
           'Northeast - Size Class A',
           'Midwest - Size Class A',
           'South - Size Class A']

# %% [markdown]
# ### Let's generate a DataFrame containing data for the U.S. city average CPI value of all items, not seasonally adjusted.

# %%
all_items_df = df[(df['item'] == 'All items') 
           & (df['area'] == 'U.S. city average')].sort_values(by='date')

# Add monthly and yearly changes in value.
all_items_df['monthly'] = 100*all_items_df['value'].pct_change()
all_items_df['yearly'] = 100*all_items_df['value'].pct_change(periods=12)

# Drop irrelevant columns.
all_items_df = all_items_df.drop(['area','item'],axis=1)
all_items_df.head()
# Out:
#           date  value   monthly  yearly
# 0   1997-01-01  159.4       NaN     NaN
# 26  1997-02-01  159.7  0.188206     NaN
# 52  1997-03-01  159.8  0.062617     NaN
# 78  1997-04-01  159.9  0.062578     NaN
# 104 1997-05-01  159.9  0.000000     NaN

# %%
all_items_df.iplot(kind='scatter',x='date',y='value',
                 title='U.S. City Average Value, All Items, Not Seasonally Adjusted',
                 xTitle='Date',
                 yTitle='CPI Value',
                 color='black')
# Out:
# <div>                            <div id="0f1bf915-3112-4e58-9fb2-1282c6c8ca12" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("0f1bf915-3112-4e58-9fb2-1282c6c8ca12")) {                    Plotly.newPlot(                        "0f1bf915-3112-4e58-9fb2-1282c6c8ca12",                        [{"line":{"color":"rgba(0, 0, 0, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"value","text":"","x":["1997-01-01","1997-02-01","1997-03-01","1997-04-01","1997-05-01","1997-06-01","1997-07-01","1997-08-01","1997-09-01","1997-10-01","1997-11-01","1997-12-01","1998-01-01","1998-02-01","1998-03-01","1998-04-01","1998-05-01","1998-06-01","1998-07-01","1998-08-01","1998-09-01","1998-10-01","1998-11-01","1998-12-01","1999-01-01","1999-02-01","1999-03-01","1999-04-01","1999-05-01","1999-06-01","1999-07-01","1999-08-01","1999-09-01","1999-10-01","1999-11-01","1999-12-01","2000-01-01","2000-02-01","2000-03-01","2000-04-01","2000-05-01","2000-06-01","2000-07-01","2000-08-01","2000-09-01","2000-10-01","2000-11-01","2000-12-01","2001-01-01","2001-02-01","2001-03-01","2001-04-01","2001-05-01","2001-06-01","2001-07-01","2001-08-01","2001-09-01","2001-10-01","2001-11-01","2001-12-01","2002-01-01","2002-02-01","2002-03-01","2002-04-01","2002-05-01","2002-06-01","2002-07-01","2002-08-01","2002-09-01","2002-10-01","2002-11-01","2002-12-01","2003-01-01","2003-02-01","2003-03-01","2003-04-01","2003-05-01","2003-06-01","2003-07-01","2003-08-01","2003-09-01","2003-10-01","2003-11-01","2003-12-01","2004-01-01","2004-02-01","2004-03-01","2004-04-01","2004-05-01","2004-06-01","2004-07-01","2004-08-01","2004-09-01","2004-10-01","2004-11-01","2004-12-01","2005-01-01","2005-02-01","2005-03-01","2005-04-01","2005-05-01","2005-06-01","2005-07-01","2005-08-01","2005-09-01","2005-10-01","2005-11-01","2005-12-01","2006-01-01","2006-02-01","2006-03-01","2006-04-01","2006-05-01","2006-06-01","2006-07-01","2006-08-01","2006-09-01","2006-10-01","2006-11-01","2006-12-01","2007-01-01","2007-02-01","2007-03-01","2007-04-01","2007-05-01","2007-06-01","2007-07-01","2007-08-01","2007-09-01","2007-10-01","2007-11-01","2007-12-01","2008-01-01","2008-02-01","2008-03-01","2008-04-01","2008-05-01","2008-06-01","2008-07-01","2008-08-01","2008-09-01","2008-10-01","2008-11-01","2008-12-01","2009-01-01","2009-02-01","2009-03-01","2009-04-01","2009-05-01","2009-06-01","2009-07-01","2009-08-01","2009-09-01","2009-10-01","2009-11-01","2009-12-01","2010-01-01","2010-02-01","2010-03-01","2010-04-01","2010-05-01","2010-06-01","2010-07-01","2010-08-01","2010-09-01","2010-10-01","2010-11-01","2010-12-01","2011-01-01","2011-02-01","2011-03-01","2011-04-01","2011-05-01","2011-06-01","2011-07-01","2011-08-01","2011-09-01","2011-10-01","2011-11-01","2011-12-01","2012-01-01","2012-02-01","2012-03-01","2012-04-01","2012-05-01","2012-06-01","2012-07-01","2012-08-01","2012-09-01","2012-10-01","2012-11-01","2012-12-01","2013-01-01","2013-02-01","2013-03-01","2013-04-01","2013-05-01","2013-06-01","2013-07-01","2013-08-01","2013-09-01","2013-10-01","2013-11-01","2013-12-01","2014-01-01","2014-02-01","2014-03-01","2014-04-01","2014-05-01","2014-06-01","2014-07-01","2014-08-01","2014-09-01","2014-10-01","2014-11-01","2014-12-01","2015-01-01","2015-02-01","2015-03-01","2015-04-01","2015-05-01","2015-06-01","2015-07-01","2015-08-01","2015-09-01","2015-10-01","2015-11-01","2015-12-01","2016-01-01","2016-02-01","2016-03-01","2016-04-01","2016-05-01","2016-06-01","2016-07-01","2016-08-01","2016-09-01","2016-10-01","2016-11-01","2016-12-01","2017-01-01","2017-02-01","2017-03-01","2017-04-01","2017-05-01","2017-06-01","2017-07-01","2017-08-01","2017-09-01","2017-10-01","2017-11-01","2017-12-01","2018-01-01","2018-02-01","2018-03-01","2018-04-01","2018-05-01","2018-06-01","2018-07-01","2018-08-01","2018-09-01","2018-10-01","2018-11-01","2018-12-01","2019-01-01","2019-02-01","2019-03-01","2019-04-01","2019-05-01","2019-06-01","2019-07-01","2019-08-01","2019-09-01","2019-10-01","2019-11-01","201 ...

# %%
all_items_df.iplot(kind='scatter',x='date',y='monthly',
                 title='MoM Change in U.S. City Average Value, All Items, Not Seasonally Adjusted',
                 xTitle='Date',
                 yTitle='MoM Change in CPI Value (%)',
                 color='black')
# Out:
# <div>                            <div id="4ed533d7-8787-40af-9b00-3f833b3fb5e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("4ed533d7-8787-40af-9b00-3f833b3fb5e5")) {                    Plotly.newPlot(                        "4ed533d7-8787-40af-9b00-3f833b3fb5e5",                        [{"line":{"color":"rgba(0, 0, 0, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"monthly","text":"","x":["1997-01-01","1997-02-01","1997-03-01","1997-04-01","1997-05-01","1997-06-01","1997-07-01","1997-08-01","1997-09-01","1997-10-01","1997-11-01","1997-12-01","1998-01-01","1998-02-01","1998-03-01","1998-04-01","1998-05-01","1998-06-01","1998-07-01","1998-08-01","1998-09-01","1998-10-01","1998-11-01","1998-12-01","1999-01-01","1999-02-01","1999-03-01","1999-04-01","1999-05-01","1999-06-01","1999-07-01","1999-08-01","1999-09-01","1999-10-01","1999-11-01","1999-12-01","2000-01-01","2000-02-01","2000-03-01","2000-04-01","2000-05-01","2000-06-01","2000-07-01","2000-08-01","2000-09-01","2000-10-01","2000-11-01","2000-12-01","2001-01-01","2001-02-01","2001-03-01","2001-04-01","2001-05-01","2001-06-01","2001-07-01","2001-08-01","2001-09-01","2001-10-01","2001-11-01","2001-12-01","2002-01-01","2002-02-01","2002-03-01","2002-04-01","2002-05-01","2002-06-01","2002-07-01","2002-08-01","2002-09-01","2002-10-01","2002-11-01","2002-12-01","2003-01-01","2003-02-01","2003-03-01","2003-04-01","2003-05-01","2003-06-01","2003-07-01","2003-08-01","2003-09-01","2003-10-01","2003-11-01","2003-12-01","2004-01-01","2004-02-01","2004-03-01","2004-04-01","2004-05-01","2004-06-01","2004-07-01","2004-08-01","2004-09-01","2004-10-01","2004-11-01","2004-12-01","2005-01-01","2005-02-01","2005-03-01","2005-04-01","2005-05-01","2005-06-01","2005-07-01","2005-08-01","2005-09-01","2005-10-01","2005-11-01","2005-12-01","2006-01-01","2006-02-01","2006-03-01","2006-04-01","2006-05-01","2006-06-01","2006-07-01","2006-08-01","2006-09-01","2006-10-01","2006-11-01","2006-12-01","2007-01-01","2007-02-01","2007-03-01","2007-04-01","2007-05-01","2007-06-01","2007-07-01","2007-08-01","2007-09-01","2007-10-01","2007-11-01","2007-12-01","2008-01-01","2008-02-01","2008-03-01","2008-04-01","2008-05-01","2008-06-01","2008-07-01","2008-08-01","2008-09-01","2008-10-01","2008-11-01","2008-12-01","2009-01-01","2009-02-01","2009-03-01","2009-04-01","2009-05-01","2009-06-01","2009-07-01","2009-08-01","2009-09-01","2009-10-01","2009-11-01","2009-12-01","2010-01-01","2010-02-01","2010-03-01","2010-04-01","2010-05-01","2010-06-01","2010-07-01","2010-08-01","2010-09-01","2010-10-01","2010-11-01","2010-12-01","2011-01-01","2011-02-01","2011-03-01","2011-04-01","2011-05-01","2011-06-01","2011-07-01","2011-08-01","2011-09-01","2011-10-01","2011-11-01","2011-12-01","2012-01-01","2012-02-01","2012-03-01","2012-04-01","2012-05-01","2012-06-01","2012-07-01","2012-08-01","2012-09-01","2012-10-01","2012-11-01","2012-12-01","2013-01-01","2013-02-01","2013-03-01","2013-04-01","2013-05-01","2013-06-01","2013-07-01","2013-08-01","2013-09-01","2013-10-01","2013-11-01","2013-12-01","2014-01-01","2014-02-01","2014-03-01","2014-04-01","2014-05-01","2014-06-01","2014-07-01","2014-08-01","2014-09-01","2014-10-01","2014-11-01","2014-12-01","2015-01-01","2015-02-01","2015-03-01","2015-04-01","2015-05-01","2015-06-01","2015-07-01","2015-08-01","2015-09-01","2015-10-01","2015-11-01","2015-12-01","2016-01-01","2016-02-01","2016-03-01","2016-04-01","2016-05-01","2016-06-01","2016-07-01","2016-08-01","2016-09-01","2016-10-01","2016-11-01","2016-12-01","2017-01-01","2017-02-01","2017-03-01","2017-04-01","2017-05-01","2017-06-01","2017-07-01","2017-08-01","2017-09-01","2017-10-01","2017-11-01","2017-12-01","2018-01-01","2018-02-01","2018-03-01","2018-04-01","2018-05-01","2018-06-01","2018-07-01","2018-08-01","2018-09-01","2018-10-01","2018-11-01","2018-12-01","2019-01-01","2019-02-01","2019-03-01","2019-04-01","2019-05-01","2019-06-01","2019-07-01","2019-08-01","2019-09-01","2019-10-01","2019-11-01","2 ...

# %%
all_items_df.iplot(kind='scatter',x='date',y='yearly',
                 title='YoY Change in U.S. City Average Value, All Items, Not Seasonally Adjusted',
                 xTitle='Date',
                 yTitle='YoY Change in CPI Value (%)',`
                 color='black')
# Out:
#   Input In [49]
#     yTitle='YoY Change in CPI Value (%)',`
#                                          ^
# SyntaxError: invalid syntax
